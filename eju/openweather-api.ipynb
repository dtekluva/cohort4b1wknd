# %%
import requests

# %%
# # THIS IS THE CITY ID OF INSTABUL
# city_id = "745042"
# url = "https://api.openweathermap.org/data/2.5/forecast?id=" + city_id + "&APPID=7d740708090dd65a4ddd2db1f445504e"

# %%
# response = requests.get(url)

# %%
# response.json()

# %%
# THIS IS THE CITY ID OF LAGOS,NIGERIA
city_id = "2332453"
url = "https://api.openweathermap.org/data/2.5/forecast?id=" + city_id + "&APPID=7d740708090dd65a4ddd2db1f445504e"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1619276400,
#    'main': {'temp': 305.15,
#     'feels_like': 312.15,
#     'temp_min': 304.92,
#     'temp_max': 305.15,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 66,
#     'temp_kf': 0.23},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 3.79, 'deg': 195, 'gust': 3.92},
#    'visibility': 10000,
#    'pop': 0.75,
#    'rain': {'3h': 0.21},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-24 15:00:00'},
#   {'dt': 1619287200,
#    'main': {'temp': 303.69,
#     'feels_like': 309.82,
#     'temp_min': 300.77,
#     'temp_max': 303.69,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 71,
#     'temp_kf': 2.92},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 2.76, 'deg': 170, 'gust': 6.09},
#    'visibility': 10000,
#    'pop': 0.79,
#    'rain': {'3h': 0.42},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-24 18:00:00'},
#   {'dt': 1619298000,
#    'main': {'temp': 301.2,
#     'feels_like': 305.69,
#     'temp_min': 299.23,
#     'temp_max': 301.2,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 82,
#     'temp_kf': 1.97},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 1.85, 'deg': 180, 'gust': 5.81},
#    'visibility': 10000,
#    'pop': 0.73,
#    'rain': {'3h': 1.08},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-24 21:00:00'},
#   {'dt': 1619308800,
#    'main': {'temp': 298.32,
#     'feels_like': 299.24,
#     'temp_min': 298.32,
#     'temp_max': 298.32,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1011,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 2.81, 'deg': 295, 'gust': 6.23},
#    'visibility': 10000,
#    'pop': 0.93,
#    'rain': {'3h': 2.27},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-25 00:00:00'},
#   {'dt': 1619319600,
#    'main': {'temp': 296.12,
#     'feels_like': 296.67,
#     'temp_min': 296.12,
#     'temp_max': 296.12,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1008,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.68, 'deg': 210, 'gust': 2.48},
#    'visibility': 10000,
#    'pop': 0.57,
#    'rain': {'3h': 0.42},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-25 03:00:00'},
#   {'dt': 1619330400,
#    'main': {'temp': 297.92,
#     'feels_like': 298.72,
#     'temp_min': 297.92,
#     'temp_max': 297.92,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.98, 'deg': 189, 'gust': 6.47},
#    'visibility': 10000,
#    'pop': 0.49,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-25 06:00:00'},
#   {'dt': 1619341200,
#    'main': {'temp': 302.8,
#     'feels_like': 307.13,
#     'temp_min': 302.8,
#     'temp_max': 302.8,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1011,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.22, 'deg': 193, 'gust': 5.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-25 09:00:00'},
#   {'dt': 1619352000,
#    'main': {'temp': 305.58,
#     'feels_like': 310.3,
#     'temp_min': 305.58,
#     'temp_max': 305.58,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.8, 'deg': 193, 'gust': 3.88},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-25 12:00:00'},
#   {'dt': 1619362800,
#    'main': {'temp': 305.29,
#     'feels_like': 309.95,
#     'temp_min': 305.29,
#     'temp_max': 305.29,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1007,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 74},
#    'wind': {'speed': 3.84, 'deg': 208, 'gust': 3.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-25 15:00:00'},
#   {'dt': 1619373600,
#    'main': {'temp': 300.58,
#     'feels_like': 303.87,
#     'temp_min': 300.58,
#     'temp_max': 300.58,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1008,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 2.35, 'deg': 224, 'gust': 5.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-25 18:00:00'},
#   {'dt': 1619384400,
#    'main': {'temp': 300.11,
#     'feels_like': 303.18,
#     'temp_min': 300.11,
#     'temp_max': 300.11,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 1.98, 'deg': 235, 'gust': 5.95},
#    'visibility': 10000,
#    'pop': 0.33,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-25 21:00:00'},
#   {'dt': 1619395200,
#    'main': {'temp': 299.56,
#     'feels_like': 299.56,
#     'temp_min': 299.56,
#     'temp_max': 299.56,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 1.8, 'deg': 223, 'gust': 4.3},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-26 00:00:00'},
#   {'dt': 1619406000,
#    'main': {'temp': 298.99,
#     'feels_like': 300.03,
#     'temp_min': 298.99,
#     'temp_max': 298.99,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 1.29, 'deg': 227, 'gust': 2.37},
#    'visibility': 10000,
#    'pop': 0.24,
#    'rain': {'3h': 0.77},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-26 03:00:00'},
#   {'dt': 1619416800,
#    'main': {'temp': 298.87,
#     'feels_like': 299.9,
#     'temp_min': 298.87,
#     'temp_max': 298.87,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1011,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 1.38, 'deg': 253, 'gust': 3.01},
#    'visibility': 10000,
#    'pop': 0.36,
#    'rain': {'3h': 0.54},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-26 06:00:00'},
#   {'dt': 1619427600,
#    'main': {'temp': 304.26,
#     'feels_like': 309.57,
#     'temp_min': 304.26,
#     'temp_max': 304.26,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1012,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 23},
#    'wind': {'speed': 2.73, 'deg': 217, 'gust': 3.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-26 09:00:00'},
#   {'dt': 1619438400,
#    'main': {'temp': 306.34,
#     'feels_like': 311.4,
#     'temp_min': 306.34,
#     'temp_max': 306.34,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 3.96, 'deg': 209, 'gust': 2.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-26 12:00:00'},
#   {'dt': 1619449200,
#    'main': {'temp': 305.35,
#     'feels_like': 310.08,
#     'temp_min': 305.35,
#     'temp_max': 305.35,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1007,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 4.6, 'deg': 201, 'gust': 4.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-26 15:00:00'},
#   {'dt': 1619460000,
#    'main': {'temp': 301.08,
#     'feels_like': 304.63,
#     'temp_min': 301.08,
#     'temp_max': 301.08,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1007,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 3.33, 'deg': 205, 'gust': 7.6},
#    'visibility': 10000,
#    'pop': 0.04,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-26 18:00:00'},
#   {'dt': 1619470800,
#    'main': {'temp': 300.15,
#     'feels_like': 303.27,
#     'temp_min': 300.15,
#     'temp_max': 300.15,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 1.86, 'deg': 258, 'gust': 5.18},
#    'visibility': 10000,
#    'pop': 0.51,
#    'rain': {'3h': 0.54},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-26 21:00:00'},
#   {'dt': 1619481600,
#    'main': {'temp': 299.81,
#     'feels_like': 299.81,
#     'temp_min': 299.81,
#     'temp_max': 299.81,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 1.84, 'deg': 229, 'gust': 4.76},
#    'visibility': 10000,
#    'pop': 0.51,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-27 00:00:00'},
#   {'dt': 1619492400,
#    'main': {'temp': 299.45,
#     'feels_like': 299.45,
#     'temp_min': 299.45,
#     'temp_max': 299.45,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1008,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.62, 'deg': 207, 'gust': 1.14},
#    'visibility': 10000,
#    'pop': 0.11,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-27 03:00:00'},
#   {'dt': 1619503200,
#    'main': {'temp': 298.98,
#     'feels_like': 299.94,
#     'temp_min': 298.98,
#     'temp_max': 298.98,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 203, 'gust': 3.15},
#    'visibility': 10000,
#    'pop': 0.73,
#    'rain': {'3h': 2.15},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-27 06:00:00'},
#   {'dt': 1619514000,
#    'main': {'temp': 302.98,
#     'feels_like': 307.55,
#     'temp_min': 302.98,
#     'temp_max': 302.98,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.43, 'deg': 248, 'gust': 7},
#    'visibility': 10000,
#    'pop': 0.05,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-27 09:00:00'},
#   {'dt': 1619524800,
#    'main': {'temp': 305.87,
#     'feels_like': 310.34,
#     'temp_min': 305.87,
#     'temp_max': 305.87,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1008,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.68, 'deg': 222, 'gust': 3.32},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-27 12:00:00'},
#   {'dt': 1619535600,
#    'main': {'temp': 303.43,
#     'feels_like': 307.65,
#     'temp_min': 303.43,
#     'temp_max': 303.43,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1007,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.49, 'deg': 207, 'gust': 4.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-27 15:00:00'},
#   {'dt': 1619546400,
#    'main': {'temp': 300.88,
#     'feels_like': 304.58,
#     'temp_min': 300.88,
#     'temp_max': 300.88,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1007,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 3.18, 'deg': 201, 'gust': 6.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-27 18:00:00'},
#   {'dt': 1619557200,
#    'main': {'temp': 299.92,
#     'feels_like': 302.89,
#     'temp_min': 299.92,
#     'temp_max': 299.92,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 2.72, 'deg': 213, 'gust': 7.27},
#    'visibility': 10000,
#    'pop': 0.08,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-27 21:00:00'},
#   {'dt': 1619568000,
#    'main': {'temp': 299.51,
#     'feels_like': 299.51,
#     'temp_min': 299.51,
#     'temp_max': 299.51,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1008,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 2.09, 'deg': 221, 'gust': 5.75},
#    'visibility': 10000,
#    'pop': 0.32,
#    'rain': {'3h': 0.73},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-28 00:00:00'},
#   {'dt': 1619578800,
#    'main': {'temp': 299.07,
#     'feels_like': 300.02,
#     'temp_min': 299.07,
#     'temp_max': 299.07,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1007,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 1.9, 'deg': 210, 'gust': 4.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-28 03:00:00'},
#   {'dt': 1619589600,
#    'main': {'temp': 299.31,
#     'feels_like': 299.31,
#     'temp_min': 299.31,
#     'temp_max': 299.31,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1008,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 1.72, 'deg': 224, 'gust': 4.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-28 06:00:00'},
#   {'dt': 1619600400,
#    'main': {'temp': 304.51,
#     'feels_like': 309.32,
#     'temp_min': 304.51,
#     'temp_max': 304.51,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 3.12, 'deg': 207, 'gust': 3.67},
#    'visibility': 10000,
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-28 09:00:00'},
#   {'dt': 1619611200,
#    'main': {'temp': 305.83,
#     'feels_like': 310.87,
#     'temp_min': 305.83,
#     'temp_max': 305.83,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 3.66, 'deg': 214, 'gust': 3.51},
#    'visibility': 10000,
#    'pop': 0.53,
#    'rain': {'3h': 0.42},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-28 12:00:00'},
#   {'dt': 1619622000,
#    'main': {'temp': 305.01,
#     'feels_like': 309.32,
#     'temp_min': 305.01,
#     'temp_max': 305.01,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1007,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.97, 'deg': 212, 'gust': 4.12},
#    'visibility': 10000,
#    'pop': 0.32,
#    'rain': {'3h': 0.27},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-28 15:00:00'},
#   {'dt': 1619632800,
#    'main': {'temp': 301.01,
#     'feels_like': 304.47,
#     'temp_min': 301.01,
#     'temp_max': 301.01,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1008,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 2.91, 'deg': 202, 'gust': 6.41},
#    'visibility': 10000,
#    'pop': 0.28,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-28 18:00:00'},
#   {'dt': 1619643600,
#    'main': {'temp': 299.74,
#     'feels_like': 299.74,
#     'temp_min': 299.74,
#     'temp_max': 299.74,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 2.36, 'deg': 207, 'gust': 6.71},
#    'visibility': 10000,
#    'pop': 0.37,
#    'rain': {'3h': 0.29},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-28 21:00:00'},
#   {'dt': 1619654400,
#    'main': {'temp': 299.31,
#     'feels_like': 299.31,
#     'temp_min': 299.31,
#     'temp_max': 299.31,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 1.58, 'deg': 203, 'gust': 3.31},
#    'visibility': 10000,
#    'pop': 0.17,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-29 00:00:00'},
#   {'dt': 1619665200,
#    'main': {'temp': 298.94,
#     'feels_like': 299.9,
#     'temp_min': 298.94,
#     'temp_max': 298.94,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1008,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.7, 'deg': 234, 'gust': 3.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-04-29 03:00:00'},
#   {'dt': 1619676000,
#    'main': {'temp': 299.08,
#     'feels_like': 300.03,
#     'temp_min': 299.08,
#     'temp_max': 299.08,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 0.63, 'deg': 271, 'gust': 0.84},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-29 06:00:00'},
#   {'dt': 1619686800,
#    'main': {'temp': 304.58,
#     'feels_like': 309.2,
#     'temp_min': 304.58,
#     'temp_max': 304.58,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.23, 'deg': 222, 'gust': 2.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-29 09:00:00'},
#   {'dt': 1619697600,
#    'main': {'temp': 305.38,
#     'feels_like': 309.85,
#     'temp_min': 305.38,
#     'temp_max': 305.38,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.42, 'deg': 204, 'gust': 2.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-04-29 12:00:00'}],
#  'city': {'id': 2332453,
#   'name': 'Lagos',
#   'coord': {'lat': 6.5833, 'lon': 3.75},
#   'country': 'NG',
#   'population': 0,
#   'timezone': 3600,
#   'sunrise': 1619242407,
#   'sunset': 1619286747}}

# %%
data = response.json()

# %%
type(data)
# Out:
# dict

# %%
data.get("list")
# Out:
# [{'dt': 1619276400,
#   'main': {'temp': 305.15,
#    'feels_like': 312.15,
#    'temp_min': 304.92,
#    'temp_max': 305.15,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1008,
#    'humidity': 66,
#    'temp_kf': 0.23},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 75},
#   'wind': {'speed': 3.79, 'deg': 195, 'gust': 3.92},
#   'visibility': 10000,
#   'pop': 0.75,
#   'rain': {'3h': 0.21},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-24 15:00:00'},
#  {'dt': 1619287200,
#   'main': {'temp': 303.69,
#    'feels_like': 309.82,
#    'temp_min': 300.77,
#    'temp_max': 303.69,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1008,
#    'humidity': 71,
#    'temp_kf': 2.92},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 81},
#   'wind': {'speed': 2.76, 'deg': 170, 'gust': 6.09},
#   'visibility': 10000,
#   'pop': 0.79,
#   'rain': {'3h': 0.42},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-24 18:00:00'},
#  {'dt': 1619298000,
#   'main': {'temp': 301.2,
#    'feels_like': 305.69,
#    'temp_min': 299.23,
#    'temp_max': 301.2,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 82,
#    'temp_kf': 1.97},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 49},
#   'wind': {'speed': 1.85, 'deg': 180, 'gust': 5.81},
#   'visibility': 10000,
#   'pop': 0.73,
#   'rain': {'3h': 1.08},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-24 21:00:00'},
#  {'dt': 1619308800,
#   'main': {'temp': 298.32,
#    'feels_like': 299.24,
#    'temp_min': 298.32,
#    'temp_max': 298.32,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1011,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 58},
#   'wind': {'speed': 2.81, 'deg': 295, 'gust': 6.23},
#   'visibility': 10000,
#   'pop': 0.93,
#   'rain': {'3h': 2.27},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-25 00:00:00'},
#  {'dt': 1619319600,
#   'main': {'temp': 296.12,
#    'feels_like': 296.67,
#    'temp_min': 296.12,
#    'temp_max': 296.12,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1008,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.68, 'deg': 210, 'gust': 2.48},
#   'visibility': 10000,
#   'pop': 0.57,
#   'rain': {'3h': 0.42},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-25 03:00:00'},
#  {'dt': 1619330400,
#   'main': {'temp': 297.92,
#    'feels_like': 298.72,
#    'temp_min': 297.92,
#    'temp_max': 297.92,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.98, 'deg': 189, 'gust': 6.47},
#   'visibility': 10000,
#   'pop': 0.49,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-25 06:00:00'},
#  {'dt': 1619341200,
#   'main': {'temp': 302.8,
#    'feels_like': 307.13,
#    'temp_min': 302.8,
#    'temp_max': 302.8,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1011,
#    'humidity': 69,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.22, 'deg': 193, 'gust': 5.04},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-25 09:00:00'},
#  {'dt': 1619352000,
#   'main': {'temp': 305.58,
#    'feels_like': 310.3,
#    'temp_min': 305.58,
#    'temp_max': 305.58,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 57,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.8, 'deg': 193, 'gust': 3.88},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-25 12:00:00'},
#  {'dt': 1619362800,
#   'main': {'temp': 305.29,
#    'feels_like': 309.95,
#    'temp_min': 305.29,
#    'temp_max': 305.29,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1007,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 74},
#   'wind': {'speed': 3.84, 'deg': 208, 'gust': 3.51},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-25 15:00:00'},
#  {'dt': 1619373600,
#   'main': {'temp': 300.58,
#    'feels_like': 303.87,
#    'temp_min': 300.58,
#    'temp_max': 300.58,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1008,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 52},
#   'wind': {'speed': 2.35, 'deg': 224, 'gust': 5.34},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-25 18:00:00'},
#  {'dt': 1619384400,
#   'main': {'temp': 300.11,
#    'feels_like': 303.18,
#    'temp_min': 300.11,
#    'temp_max': 300.11,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 51},
#   'wind': {'speed': 1.98, 'deg': 235, 'gust': 5.95},
#   'visibility': 10000,
#   'pop': 0.33,
#   'rain': {'3h': 0.13},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-25 21:00:00'},
#  {'dt': 1619395200,
#   'main': {'temp': 299.56,
#    'feels_like': 299.56,
#    'temp_min': 299.56,
#    'temp_max': 299.56,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 62},
#   'wind': {'speed': 1.8, 'deg': 223, 'gust': 4.3},
#   'visibility': 10000,
#   'pop': 0.03,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-26 00:00:00'},
#  {'dt': 1619406000,
#   'main': {'temp': 298.99,
#    'feels_like': 300.03,
#    'temp_min': 298.99,
#    'temp_max': 298.99,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 92,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 1.29, 'deg': 227, 'gust': 2.37},
#   'visibility': 10000,
#   'pop': 0.24,
#   'rain': {'3h': 0.77},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-26 03:00:00'},
#  {'dt': 1619416800,
#   'main': {'temp': 298.87,
#    'feels_like': 299.9,
#    'temp_min': 298.87,
#    'temp_max': 298.87,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1011,
#    'humidity': 92,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 72},
#   'wind': {'speed': 1.38, 'deg': 253, 'gust': 3.01},
#   'visibility': 10000,
#   'pop': 0.36,
#   'rain': {'3h': 0.54},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-26 06:00:00'},
#  {'dt': 1619427600,
#   'main': {'temp': 304.26,
#    'feels_like': 309.57,
#    'temp_min': 304.26,
#    'temp_max': 304.26,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 65,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 23},
#   'wind': {'speed': 2.73, 'deg': 217, 'gust': 3.11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-26 09:00:00'},
#  {'dt': 1619438400,
#   'main': {'temp': 306.34,
#    'feels_like': 311.4,
#    'temp_min': 306.34,
#    'temp_max': 306.34,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 55,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 47},
#   'wind': {'speed': 3.96, 'deg': 209, 'gust': 2.92},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-26 12:00:00'},
#  {'dt': 1619449200,
#   'main': {'temp': 305.35,
#    'feels_like': 310.08,
#    'temp_min': 305.35,
#    'temp_max': 305.35,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1007,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 49},
#   'wind': {'speed': 4.6, 'deg': 201, 'gust': 4.73},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-26 15:00:00'},
#  {'dt': 1619460000,
#   'main': {'temp': 301.08,
#    'feels_like': 304.63,
#    'temp_min': 301.08,
#    'temp_max': 301.08,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1007,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 3.33, 'deg': 205, 'gust': 7.6},
#   'visibility': 10000,
#   'pop': 0.04,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-26 18:00:00'},
#  {'dt': 1619470800,
#   'main': {'temp': 300.15,
#    'feels_like': 303.27,
#    'temp_min': 300.15,
#    'temp_max': 300.15,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 1.86, 'deg': 258, 'gust': 5.18},
#   'visibility': 10000,
#   'pop': 0.51,
#   'rain': {'3h': 0.54},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-26 21:00:00'},
#  {'dt': 1619481600,
#   'main': {'temp': 299.81,
#    'feels_like': 299.81,
#    'temp_min': 299.81,
#    'temp_max': 299.81,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 84},
#   'wind': {'speed': 1.84, 'deg': 229, 'gust': 4.76},
#   'visibility': 10000,
#   'pop': 0.51,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-27 00:00:00'},
#  {'dt': 1619492400,
#   'main': {'temp': 299.45,
#    'feels_like': 299.45,
#    'temp_min': 299.45,
#    'temp_max': 299.45,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1008,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.62, 'deg': 207, 'gust': 1.14},
#   'visibility': 10000,
#   'pop': 0.11,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-27 03:00:00'},
#  {'dt': 1619503200,
#   'main': {'temp': 298.98,
#    'feels_like': 299.94,
#    'temp_min': 298.98,
#    'temp_max': 298.98,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.74, 'deg': 203, 'gust': 3.15},
#   'visibility': 10000,
#   'pop': 0.73,
#   'rain': {'3h': 2.15},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-27 06:00:00'},
#  {'dt': 1619514000,
#   'main': {'temp': 302.98,
#    'feels_like': 307.55,
#    'temp_min': 302.98,
#    'temp_max': 302.98,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 69,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 4.43, 'deg': 248, 'gust': 7},
#   'visibility': 10000,
#   'pop': 0.05,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-27 09:00:00'},
#  {'dt': 1619524800,
#   'main': {'temp': 305.87,
#    'feels_like': 310.34,
#    'temp_min': 305.87,
#    'temp_max': 305.87,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1008,
#    'humidity': 55,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.68, 'deg': 222, 'gust': 3.32},
#   'visibility': 10000,
#   'pop': 0.03,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-27 12:00:00'},
#  {'dt': 1619535600,
#   'main': {'temp': 303.43,
#    'feels_like': 307.65,
#    'temp_min': 303.43,
#    'temp_max': 303.43,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1007,
#    'humidity': 65,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.49, 'deg': 207, 'gust': 4.31},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-27 15:00:00'},
#  {'dt': 1619546400,
#   'main': {'temp': 300.88,
#    'feels_like': 304.58,
#    'temp_min': 300.88,
#    'temp_max': 300.88,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1007,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 96},
#   'wind': {'speed': 3.18, 'deg': 201, 'gust': 6.94},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-27 18:00:00'},
#  {'dt': 1619557200,
#   'main': {'temp': 299.92,
#    'feels_like': 302.89,
#    'temp_min': 299.92,
#    'temp_max': 299.92,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 2.72, 'deg': 213, 'gust': 7.27},
#   'visibility': 10000,
#   'pop': 0.08,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-27 21:00:00'},
#  {'dt': 1619568000,
#   'main': {'temp': 299.51,
#    'feels_like': 299.51,
#    'temp_min': 299.51,
#    'temp_max': 299.51,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1008,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 59},
#   'wind': {'speed': 2.09, 'deg': 221, 'gust': 5.75},
#   'visibility': 10000,
#   'pop': 0.32,
#   'rain': {'3h': 0.73},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-28 00:00:00'},
#  {'dt': 1619578800,
#   'main': {'temp': 299.07,
#    'feels_like': 300.02,
#    'temp_min': 299.07,
#    'temp_max': 299.07,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1007,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 1.9, 'deg': 210, 'gust': 4.1},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-28 03:00:00'},
#  {'dt': 1619589600,
#   'main': {'temp': 299.31,
#    'feels_like': 299.31,
#    'temp_min': 299.31,
#    'temp_max': 299.31,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1008,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 93},
#   'wind': {'speed': 1.72, 'deg': 224, 'gust': 4.11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-28 06:00:00'},
#  {'dt': 1619600400,
#   'main': {'temp': 304.51,
#    'feels_like': 309.32,
#    'temp_min': 304.51,
#    'temp_max': 304.51,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 62,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 56},
#   'wind': {'speed': 3.12, 'deg': 207, 'gust': 3.67},
#   'visibility': 10000,
#   'pop': 0.04,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-28 09:00:00'},
#  {'dt': 1619611200,
#   'main': {'temp': 305.83,
#    'feels_like': 310.87,
#    'temp_min': 305.83,
#    'temp_max': 305.83,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 57,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 73},
#   'wind': {'speed': 3.66, 'deg': 214, 'gust': 3.51},
#   'visibility': 10000,
#   'pop': 0.53,
#   'rain': {'3h': 0.42},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-28 12:00:00'},
#  {'dt': 1619622000,
#   'main': {'temp': 305.01,
#    'feels_like': 309.32,
#    'temp_min': 305.01,
#    'temp_max': 305.01,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1007,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 3.97, 'deg': 212, 'gust': 4.12},
#   'visibility': 10000,
#   'pop': 0.32,
#   'rain': {'3h': 0.27},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-28 15:00:00'},
#  {'dt': 1619632800,
#   'main': {'temp': 301.01,
#    'feels_like': 304.47,
#    'temp_min': 301.01,
#    'temp_max': 301.01,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1008,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 81},
#   'wind': {'speed': 2.91, 'deg': 202, 'gust': 6.41},
#   'visibility': 10000,
#   'pop': 0.28,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-28 18:00:00'},
#  {'dt': 1619643600,
#   'main': {'temp': 299.74,
#    'feels_like': 299.74,
#    'temp_min': 299.74,
#    'temp_max': 299.74,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 56},
#   'wind': {'speed': 2.36, 'deg': 207, 'gust': 6.71},
#   'visibility': 10000,
#   'pop': 0.37,
#   'rain': {'3h': 0.29},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-28 21:00:00'},
#  {'dt': 1619654400,
#   'main': {'temp': 299.31,
#    'feels_like': 299.31,
#    'temp_min': 299.31,
#    'temp_max': 299.31,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 75},
#   'wind': {'speed': 1.58, 'deg': 203, 'gust': 3.31},
#   'visibility': 10000,
#   'pop': 0.17,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-29 00:00:00'},
#  {'dt': 1619665200,
#   'main': {'temp': 298.94,
#    'feels_like': 299.9,
#    'temp_min': 298.94,
#    'temp_max': 298.94,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1008,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.7, 'deg': 234, 'gust': 3.73},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-04-29 03:00:00'},
#  {'dt': 1619676000,
#   'main': {'temp': 299.08,
#    'feels_like': 300.03,
#    'temp_min': 299.08,
#    'temp_max': 299.08,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 0.63, 'deg': 271, 'gust': 0.84},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-29 06:00:00'},
#  {'dt': 1619686800,
#   'main': {'temp': 304.58,
#    'feels_like': 309.2,
#    'temp_min': 304.58,
#    'temp_max': 304.58,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1010,
#    'humidity': 61,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 2.23, 'deg': 222, 'gust': 2.31},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-29 09:00:00'},
#  {'dt': 1619697600,
#   'main': {'temp': 305.38,
#    'feels_like': 309.85,
#    'temp_min': 305.38,
#    'temp_max': 305.38,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1009,
#    'humidity': 57,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 3.42, 'deg': 204, 'gust': 2.78},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-04-29 12:00:00'}]

# %%
n=0
data.get("list")[n].get("dt_txt")
# Out:
# '2021-04-24 15:00:00'

# %%
n=3
data.get("list")[3].get("dt_txt")
# Out:
# '2021-04-25 00:00:00'

# %%
n=0
while n < 40:
    date= data.get("list")[3].get("dt_txt")
    
    print (date)
    
    n+=1
# Out:
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00
# 2021-04-25 00:00:00

# %%
# n=0  CHECK FOR THE CORRECT T SCRIPT
# while n < 40:
#     length_of_date= len(data.get("list")[3].get("dt_txt"))
    
#     print (date)
    
#     n+=1

# %%
n=0

while n < 40:
    date = data.get("list")[n].get("main").get("temp")
    
    print (date)
    
    n+=1
# Out:
# 305.15
# 303.69
# 301.2
# 298.32
# 296.12
# 297.92
# 302.8
# 305.58
# 305.29
# 300.58
# 300.11
# 299.56
# 298.99
# 298.87
# 304.26
# 306.34
# 305.35
# 301.08
# 300.15
# 299.81
# 299.45
# 298.98
# 302.98
# 305.87
# 303.43
# 300.88
# 299.92
# 299.51
# 299.07
# 299.31
# 304.51
# 305.83
# 305.01
# 301.01
# 299.74
# 299.31
# 298.94
# 299.08
# 304.58
# 305.38

# %%
n=0

while n < 40:
    date = data.get("list")[n].get("wind").get("speed")
    
    print (date)
    
    n+=1
# Out:
# 3.79
# 2.76
# 1.85
# 2.81
# 1.68
# 1.98
# 3.22
# 3.8
# 3.84
# 2.35
# 1.98
# 1.8
# 1.29
# 1.38
# 2.73
# 3.96
# 4.6
# 3.33
# 1.86
# 1.84
# 0.62
# 1.74
# 4.43
# 3.68
# 3.49
# 3.18
# 2.72
# 2.09
# 1.9
# 1.72
# 3.12
# 3.66
# 3.97
# 2.91
# 2.36
# 1.58
# 1.7
# 0.63
# 2.23
# 3.42

# %%
n=0

while n < 40:
    date = data.get("list")[n].get("dt_txt")
    temp = data.get("list")[n].get("main").get("temp")
    wind = data.get("list")[n].get("wind").get("speed")
    weather = data.get("list")[n].get("weather")[0].get("description")
    
#     print (date,temp,wind,weather)
    
    print (date.center(15), str(temp).center(15), str(wind).center(15), weather.rjust(20))
    
    n+=1
# Out:
# 2021-04-24 15:00:00      305.15           3.79                light rain
# 2021-04-24 18:00:00      303.69           2.76                light rain
# 2021-04-24 21:00:00      301.2            1.85                light rain
# 2021-04-25 00:00:00      298.32           2.81                light rain
# 2021-04-25 03:00:00      296.12           1.68                light rain
# 2021-04-25 06:00:00      297.92           1.98           overcast clouds
# 2021-04-25 09:00:00      302.8            3.22           overcast clouds
# 2021-04-25 12:00:00      305.58           3.8            overcast clouds
# 2021-04-25 15:00:00      305.29           3.84             broken clouds
# 2021-04-25 18:00:00      300.58           2.35             broken clouds
# 2021-04-25 21:00:00      300.11           1.98                light rain
# 2021-04-26 00:00:00      299.56           1.8              broken clouds
# 2021-04-26 03:00:00      298.99           1.29                light rain
# 2021-04-26 06:00:00      298.87           1.38                light rain
# 2021-04-26 09:00:00      304.26           2.73                few clouds
# 2021-04-26 12:00:00      306.34           3.96          scattered clouds
# 2021-04-26 15:00:00      305.35           4.6           scattered clouds
# 2021-04-26 18:00:00      301.08           3.33          scattered clouds
# 2021-04-26 21:00:00      300.15           1.86                light rain
# 2021-04-27 00:00:00      299.81           1.84             broken clouds
# 2021-04-27 03:00:00      299.45           0.62           overcast clouds
# 2021-04-27 06:00:00      298.98           1.74                light rain
# 2021-04-27 09:00:00      302.98           4.43           overcast clouds
# 2021-04-27 12:00:00      305.87           3.68           overcast clouds
# 2021-04-27 15:00:00      303.43           3.49           overcast clouds
# 2021-04-27 18:00:00      300.88           3.18           overcast clouds
# 2021-04-27 21:00:00      299.92           2.72          scattered clouds
# 2021-04-28 00:00:00      299.51           2.09                light rain
# 2021-04-28 03:00:00      299.07           1.9            overcast clouds
# 2021-04-28 06:00:00      299.31           1.72           overcast clouds
# 2021-04-28 09:00:00      304.51           3.12             broken clouds
# 2021-04-28 12:00:00      305.83           3.66                light rain
# 2021-04-28 15:00:00      305.01           3.97                light rain
# 2021-04-28 18:00:00      301.01           2.91             broken clouds
# 2021-04-28 21:00:00      299.74           2.36                light rain
# 2021-04-29 00:00:00      299.31           1.58             broken clouds
# 2021-04-29 03:00:00      298.94           1.7            overcast clouds
# 2021-04-29 06:00:00      299.08           0.63           overcast clouds
# 2021-04-29 09:00:00      304.58           2.23           overcast clouds
# 2021-04-29 12:00:00      305.38           3.42           overcast clouds

# %%
file_name = "openweather.csv"
file = open(file_name, "w")

# %%
n=0

while n < 40:
    date = data.get("list")[n].get("dt_txt")
    temp = data.get("list")[n].get("main").get("temp")
    wind = data.get("list")[n].get("wind").get("speed")
    weather = data.get("list")[n].get("weather")[0].get("description")
    
#     print (date,temp,wind,weather)
    
    print (date.center(15), str(temp).center(15), str(wind).center(15), weather.rjust(20))
    
    n+=1
# Out:
# 2021-04-24 15:00:00      305.15           3.79                light rain
# 2021-04-24 18:00:00      303.69           2.76                light rain
# 2021-04-24 21:00:00      301.2            1.85                light rain
# 2021-04-25 00:00:00      298.32           2.81                light rain
# 2021-04-25 03:00:00      296.12           1.68                light rain
# 2021-04-25 06:00:00      297.92           1.98           overcast clouds
# 2021-04-25 09:00:00      302.8            3.22           overcast clouds
# 2021-04-25 12:00:00      305.58           3.8            overcast clouds
# 2021-04-25 15:00:00      305.29           3.84             broken clouds
# 2021-04-25 18:00:00      300.58           2.35             broken clouds
# 2021-04-25 21:00:00      300.11           1.98                light rain
# 2021-04-26 00:00:00      299.56           1.8              broken clouds
# 2021-04-26 03:00:00      298.99           1.29                light rain
# 2021-04-26 06:00:00      298.87           1.38                light rain
# 2021-04-26 09:00:00      304.26           2.73                few clouds
# 2021-04-26 12:00:00      306.34           3.96          scattered clouds
# 2021-04-26 15:00:00      305.35           4.6           scattered clouds
# 2021-04-26 18:00:00      301.08           3.33          scattered clouds
# 2021-04-26 21:00:00      300.15           1.86                light rain
# 2021-04-27 00:00:00      299.81           1.84             broken clouds
# 2021-04-27 03:00:00      299.45           0.62           overcast clouds
# 2021-04-27 06:00:00      298.98           1.74                light rain
# 2021-04-27 09:00:00      302.98           4.43           overcast clouds
# 2021-04-27 12:00:00      305.87           3.68           overcast clouds
# 2021-04-27 15:00:00      303.43           3.49           overcast clouds
# 2021-04-27 18:00:00      300.88           3.18           overcast clouds
# 2021-04-27 21:00:00      299.92           2.72          scattered clouds
# 2021-04-28 00:00:00      299.51           2.09                light rain
# 2021-04-28 03:00:00      299.07           1.9            overcast clouds
# 2021-04-28 06:00:00      299.31           1.72           overcast clouds
# 2021-04-28 09:00:00      304.51           3.12             broken clouds
# 2021-04-28 12:00:00      305.83           3.66                light rain
# 2021-04-28 15:00:00      305.01           3.97                light rain
# 2021-04-28 18:00:00      301.01           2.91             broken clouds
# 2021-04-28 21:00:00      299.74           2.36                light rain
# 2021-04-29 00:00:00      299.31           1.58             broken clouds
# 2021-04-29 03:00:00      298.94           1.7            overcast clouds
# 2021-04-29 06:00:00      299.08           0.63           overcast clouds
# 2021-04-29 09:00:00      304.58           2.23           overcast clouds
# 2021-04-29 12:00:00      305.38           3.42           overcast clouds

# %%
file_name = "openweather.csv"
file = open(file_name, "w")

# %%
n=0

length_of_data = len(data.get("list"))

# USE A DYNAMIC CHECK FOR THE LENGTH OF THE LIST

while n < length_of_data:
    
    date = data.get("list")[n].get("dt_txt")
    temp = data.get("list")[n].get("main").get("temp")
    wind = data.get("list")[n].get("wind").get("speed")
    weather = data.get("list")[n].get("weather")[0].get("description")
    
#     print (date,temp,wind,weather)
    
    print (date.center(15), str(temp).center(15), str(wind).center(15), weather.rjust(20))
    
    file.write(f"{date.center(15)}, {str(temp).center(15)}, {str(wind).center(15)}, {weather.rjust(20)}\n")
    
    n+=1
# Out:
# 2021-04-24 15:00:00      305.15           3.79                light rain
# 2021-04-24 18:00:00      303.69           2.76                light rain
# 2021-04-24 21:00:00      301.2            1.85                light rain
# 2021-04-25 00:00:00      298.32           2.81                light rain
# 2021-04-25 03:00:00      296.12           1.68                light rain
# 2021-04-25 06:00:00      297.92           1.98           overcast clouds
# 2021-04-25 09:00:00      302.8            3.22           overcast clouds
# 2021-04-25 12:00:00      305.58           3.8            overcast clouds
# 2021-04-25 15:00:00      305.29           3.84             broken clouds
# 2021-04-25 18:00:00      300.58           2.35             broken clouds
# 2021-04-25 21:00:00      300.11           1.98                light rain
# 2021-04-26 00:00:00      299.56           1.8              broken clouds
# 2021-04-26 03:00:00      298.99           1.29                light rain
# 2021-04-26 06:00:00      298.87           1.38                light rain
# 2021-04-26 09:00:00      304.26           2.73                few clouds
# 2021-04-26 12:00:00      306.34           3.96          scattered clouds
# 2021-04-26 15:00:00      305.35           4.6           scattered clouds
# 2021-04-26 18:00:00      301.08           3.33          scattered clouds
# 2021-04-26 21:00:00      300.15           1.86                light rain
# 2021-04-27 00:00:00      299.81           1.84             broken clouds
# 2021-04-27 03:00:00      299.45           0.62           overcast clouds
# 2021-04-27 06:00:00      298.98           1.74                light rain
# 2021-04-27 09:00:00      302.98           4.43           overcast clouds
# 2021-04-27 12:00:00      305.87           3.68           overcast clouds
# 2021-04-27 15:00:00      303.43           3.49           overcast clouds
# 2021-04-27 18:00:00      300.88           3.18           overcast clouds
# 2021-04-27 21:00:00      299.92           2.72          scattered clouds
# 2021-04-28 00:00:00      299.51           2.09                light rain
# 2021-04-28 03:00:00      299.07           1.9            overcast clouds
# 2021-04-28 06:00:00      299.31           1.72           overcast clouds
# 2021-04-28 09:00:00      304.51           3.12             broken clouds
# 2021-04-28 12:00:00      305.83           3.66                light rain
# 2021-04-28 15:00:00      305.01           3.97                light rain
# 2021-04-28 18:00:00      301.01           2.91             broken clouds
# 2021-04-28 21:00:00      299.74           2.36                light rain
# 2021-04-29 00:00:00      299.31           1.58             broken clouds
# 2021-04-29 03:00:00      298.94           1.7            overcast clouds
# 2021-04-29 06:00:00      299.08           0.63           overcast clouds
# 2021-04-29 09:00:00      304.58           2.23           overcast clouds
# 2021-04-29 12:00:00      305.38           3.42           overcast clouds

# %%
file.close()
