# %%
import pandas as pd # ALIAS PD IS GENERALLY USED

# %%
# CREATING A PANDAS SERIES

# %%
values = [x**2 for x in range(30)]

# %%
values_series = pd.Series(values)

# %%
values_series.shape
# Out:
# (30,)

# %%
values_series.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
type(values_series)
# Out:
# pandas.core.series.Series

# %%
# values_series

# %%
# list(values_series.index)

# %%
names = ["ali", "ali", "chude"]
names_series = pd.Series(names)

# %%
type(names_series.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
# help(names_series)

# %%
# SOME SERIES METHODS

names_series.unique()
# Out:
# array(['ali', 'chude'], dtype=object)

# %%
values_series.mean()
values_series.max()
# PANDAS SERIES GIVE ACCESS DIRECTLY TO STATS METHODS
# Out:
# 841

# %%
values_series[0]  # INDEX NORMALLY LIKE A PYTHON LIST
values_series.iloc[0] # USING INDEX LOCATION
# Out:
# 0

# %%
# ADD A SPECIAL INDEX TO SERIES

names = ["ali", "ali", "chude"]
names_series = pd.Series(names, index = [100, 1000, 10000])

# %%
names_series.index
# Out:
# Int64Index([100, 1000, 10000], dtype='int64')

# %%
names_series[10000]
# Out:
# 'chude'

# %%
# PANDAS DATAFRAMES CREATION AND MANIPULATION

# %%
myvals = {"names":["sandra", "kunle", "sheriff", "ade"], 
          "ages": [20,32, 14, 19], 
          "ratings": ["5-stars", "3-stars", "5-stars", "2-stars"]}

# %%
my_vals_df = pd.DataFrame(myvals)
my_vals_df
# Out:
#      names  ages  ratings
# 0   sandra    20  5-stars
# 1    kunle    32  3-stars
# 2  sheriff    14  5-stars
# 3      ade    19  2-stars

# %%
my_vals_df.shape
# Out:
# (4, 3)

# %%
type(my_vals_df)
# Out:
# pandas.core.frame.DataFrame

# %%
names_series = my_vals_df["names"]  # CUT A SERIES FROM A DATAFRAME

names_series
# Out:
# 0     sandra
# 1      kunle
# 2    sheriff
# 3        ade
# Name: names, dtype: object

# %%
multi_columns = my_vals_df[["names", "ages"]]  # CUT MULTIPLE COLUMNS FROM A DATAFRAME

multi_columns
# Out:
#      names  ages
# 0   sandra    20
# 1    kunle    32
# 2  sheriff    14
# 3      ade    19

# %%
single_row = my_vals_df.iloc[1] # INDEX SINGLE ROW FROM DATAFRAME
single_row
# Out:
# names        kunle
# ages            32
# ratings    3-stars
# Name: 1, dtype: object

# %%
multiple_row = my_vals_df.iloc[[0, 3]] # INDEX SINGLE ROW FROM DATAFRAME
multiple_row
# Out:
#     names  ages  ratings
# 0  sandra    20  5-stars
# 3     ade    19  2-stars

# %%
# ADD COLUMN TO EXISTING DATAFRAME

my_vals_df
# Out:
#      names  ages  ratings
# 0   sandra    20  5-stars
# 1    kunle    32  3-stars
# 2  sheriff    14  5-stars
# 3      ade    19  2-stars

# %%
nationalities = ["Nigerian", "German", "Swedish", "Swedish"]
my_vals_df["nationality"] = nationalities
my_vals_df
# Out:
#      names  ages  ratings nationality
# 0   sandra    20  5-stars    Nigerian
# 1    kunle    32  3-stars      German
# 2  sheriff    14  5-stars     Swedish
# 3      ade    19  2-stars     Swedish

# %%
myvals = {"names":["sandra", "kunle", "sheriff", "ade"], 
          "ages": [20,32, 14, 19], 
          "ratings": ["5-stars", "3-stars", "5-stars", "2-stars"]}

q = pd.DataFrame(myvals)
q
# Out:
#      names  ages  ratings
# 0   sandra    20  5-stars
# 1    kunle    32  3-stars
# 2  sheriff    14  5-stars
# 3      ade    19  2-stars

# %%
q.iloc[[1, 2]] # .loc FETCHES ACCROSS THE ROWS BUT FETCHES FOR NUMERIC INDEXES
# Out:
#      names  ages  ratings
# 1    kunle    32  3-stars
# 2  sheriff    14  5-stars

# %%
myvals = {"names":["sandra", "kunle", "sheriff", "ade"], 
          "ages": [20,32, 14, 19], 
          "ratings": ["5-stars", "3-stars", "5-stars", "2-stars"]}

q2 = pd.DataFrame(myvals, index = ["x", "y", "z", "zx"])
q2
# Out:
#       names  ages  ratings
# x    sandra    20  5-stars
# y     kunle    32  3-stars
# z   sheriff    14  5-stars
# zx      ade    19  2-stars

# %%
q2.loc[["y", "zx"]] # .loc FETCHES ACCROSS THE ROWS BUT FETCHES FOR NON NUMERIC INDEXES
# Out:
#     names  ages  ratings
# y   kunle    32  3-stars
# zx    ade    19  2-stars

# %%
q2[["ages", "ratings"]]
# Out:
#     ages  ratings
# x     20  5-stars
# y     32  3-stars
# z     14  5-stars
# zx    19  2-stars

# %%
# CREATE DATAFRAME FROM READING IN FILES

test_file_data = pd.read_csv("test_file.csv")
test_file_data
# Out:
#       name  position  hobby  hobby_char_length
# 0     john         1  sleep                  5
# 1    sunbo         2    eat                  3
# 2   saheed         3    NaN                  5
# 3     bala         4   jump                  4
# 4  winston         5   ride                  4
# 5    kunle         6  sleep                  5
# 6    lamid         7  blink                  5
# 7    lamid         8   slap                  4

# %%
test_file_data.shape
# Out:
# (8, 4)

# %%
type(test_file_data)
# Out:
# pandas.core.frame.DataFrame

# %%
test_file_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               8 non-null      object
#  1   position           8 non-null      int64
#  2   hobby              7 non-null      object
#  3   hobby_char_length  8 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 384.0+ bytes

# %%
test_file_data.describe()
# Out:
#        position  hobby_char_length
# count   8.00000           8.000000
# mean    4.50000           4.375000
# std     2.44949           0.744024
# min     1.00000           3.000000
# 25%     2.75000           4.000000
# 50%     4.50000           4.500000
# 75%     6.25000           5.000000
# max     8.00000           5.000000

# %%
test_file_data.describe(include = "O")
# Out:
#          name  hobby
# count       8      7
# unique      7      6
# top     lamid  sleep
# freq        2      2

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 1255-3BEE
#
#  Directory of C:\Users\kboys\OneDrive\Desktop\MY DESKTOP\PERSONAL WORK\PYTHON_CLASS\datapackages\numpy pandas matplot\pandas\1_intro
#
# 12/12/2020  07:03 PM    <DIR>          .
# 12/12/2020  07:03 PM    <DIR>          ..
# 09/22/2020  04:08 PM    <DIR>          .ipynb_checkpoints
# 09/15/2020  08:39 AM         9,095,510 All_Streaming_Shows.csv
# 04/07/2020  02:23 AM               190 applicants.csv
# 02/09/2019  08:14 PM            73,054 application_data.csv
# 12/12/2020  07:03 PM         2,560,642 archive.zip
# 09/27/2020  04:52 PM            50,267 arise_application.ipynb
# 09/14/2020  09:59 AM           584,073 co2_emission.csv
# 12/04/2018  01:25 AM            40,513 countries.csv
# 02/16/2019  05:22 AM             1,368 nyc_weather.csv
# 09/24/2020  12:23 PM            83,690 PANDAS_FILEHANDLE.ipynb
# 02/16/2019  05:22 AM             2,322 pandas_intro.py
# ...

# %%
data = pd.read_csv('nyc_weather.csv')
data
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data["EST"])
# Out:
# pandas.core.series.Series

# %%
data.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
max_temp = data.Temperature.max()

# %%
data[data.Temperature == max_temp]
df = data.copy()

# %%
data.info() #TECHNICAL INFORMATION OF DATASET
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fc3bebd6a8a8> in <module>
# ----> 1 data.info() #TECHNICAL INFORMATION OF DATASET
#
# NameError: name 'data' is not defined

# %%
data.tail(7)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 24               10           3.0               0           2    NaN
# 25               10           7.0               0           2    NaN
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# ...

# %%
data.describe() ### DECRIBE METHOD GIVES A STATISTICAL OVERVIEW OF DATA
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
data.describe(include = ["O"])
# Out:
#              EST PrecipitationIn Events
# count         31              31      9
# unique        31               7      3
# top     1/5/2016               0   Rain
# freq           1              19      4

# %%
data.describe(include = "O")
# Out:
#               EST PrecipitationIn Events
# count          31              31      9
# unique         31               7      3
# top     1/24/2016               0   Rain
# freq            1              19      4

# %%
specific_cols = data[['EST','Events']] # INDEXING A DATAFRAME WITH MULTIPLE INDICES OR COLUMN NAMES

# %%
data.iloc[23] # INDEXING BY ROWS USING ILOC
# Out:
# EST                     1/24/2016
# Temperature                    28
# DewPoint                       11
# Humidity                       53
# Sea Level PressureIn        29.92
# VisibilityMiles                 8
# WindSpeedMPH                    6
# PrecipitationIn                 T
# CloudCover                      3
# Events                       Snow
# WindDirDegrees                327
# Name: 23, dtype: object

# %%
data.iloc[23:25] # SLICING A DATA FRAME BY ILOC
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 23                8           6.0               T           3   Snow
# 24               10           3.0               0           2    NaN
#
#     WindDirDegrees
# 23             327
# 24             286

# %%
data.iloc[[1,4,12,23]] # MULTIPLE INDEXING BY ROWS USING ILOC
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 1    1/2/2016           36        18        46                 30.02
# 4    1/5/2016           20        -3        41                 30.57
# 12  1/13/2016           26         4        42                 29.94
# 23  1/24/2016           28        11        53                 29.92
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 1                10           7.0               0           3    NaN
# 4                10           5.0               0           0    NaN
# 12               10          10.0               0           0    NaN
# 23                8           6.0               T           3   Snow
#
#     WindDirDegrees
# 1              275
# 4              333
# 12             284
# 23             327

# %%
data.loc[[23]]
# Out:
# EST                     1/24/2016
# Temperature                    28
# DewPoint                       11
# Humidity                       53
# Sea Level PressureIn        29.92
# VisibilityMiles                 8
# WindSpeedMPH                    6
# PrecipitationIn                 T
# CloudCover                      3
# Events                       Snow
# WindDirDegrees                327
# Name: 23, dtype: object

# %%
data[["Temperature", "DewPoint"]].loc[10:21]
# Out:
#     Temperature  DewPoint
# 10           33         8
# 11           35        15
# 12           26         4
# 13           30        12
# 14           43        31
# 15           47        37
# 16           36        23
# 17           25         6
# 18           22         3
# 19           32        15
# 20           31        11
# 21           26         6

# %%
rain_mask = data['Events']=='Rain' # FILTER DATASETS FOR WHEN IT RAINED
data[rain_mask]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
rain_mask_t_45 = (data['Events']=='Rain') | (data['Temperature']>45)  # FILTER DATASETS FOR WHEN IT RAINED AND TEMP ABOVE 45
data[rain_mask_t_45]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311
# 30             241

# %%
# data["WindSpeedMPH"].fillna(method = "bfill") # BACKWARD-FILL USING THE PREVIOUS VALUE
# data["WindSpeedMPH"].fillna(method = "ffill") # FORWARD-FILL USING THE PREVIOUS VALUE
data.fillna(data.rolling(3,min_periods=1).mean())
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
data["WindSpeedMPH"]
# Out:
# 0      8.0
# 1      7.0
# 2      8.0
# 3      9.0
# 4      5.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      8.0
# 9      NaN
# 10     NaN
# 11     6.0
# 12    10.0
# 13     5.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 18    11.0
# 19     6.0
# 20     6.0
# 21     NaN
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 26     7.0
# 27     5.0
# 28     8.0
# 29     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df.Events.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
my_data = [{"name":"Attah","age":20}, {"name":"Bolu","age":30}]

# %%
pd.DataFrame(my_data)
# Out:
#    age   name
# 0   20  Attah
# 1   30   Bolu

# %%
df.iloc[10]
# Out:
# EST                     1/11/2016
# Temperature                    33
# DewPoint                        8
# Humidity                       37
# Sea Level PressureIn        29.92
# VisibilityMiles                10
# WindSpeedMPH                  NaN
# PrecipitationIn                 0
# CloudCover                      1
# Events                          0
# WindDirDegrees                289
# Name: 10, dtype: object
