# %%
print(1+1)
# Out:
# 2

# %%
for i in range(340929929290320):pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-98828993b06a> in <module>
# ----> 1 for i in range(340929929290320):pass
#
# KeyboardInterrupt:

# %%
ali = "23"

# %%
ali
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eee0bad7d4f7> in <module>
# ----> 1 ali
#
# NameError: name 'ali' is not defined

# %% [markdown]
# #### **NOTEPAD APPLICATION**
#
# A notepad application running in command line and connected to sql as database.
#
# **Requirements :**
# -
# - PYMYSQL module
# - Pandas module
# - Windows OS
# - 2GB ram
# - Python > 3.6
# - 10gb Hard drive
#
# After cloning repository, just run "python start" inside the folder.
#
# *Make sure to start you SQL server and configure settings in the **config.py** file* .
#
# The Virtual environment data is available in requirements.txt.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\kboys\.virtualenvs\wyre_project-96kbt7kq\lib\site-packages (2.25.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kboys\.virtualenvs\wyre_project-96kbt7kq\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kboys\.virtualenvs\wyre_project-96kbt7kq\lib\site-packages (from requests) (2020.11.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kboys\.virtualenvs\wyre_project-96kbt7kq\lib\site-packages (from requests) (1.26.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\kboys\.virtualenvs\wyre_project-96kbt7kq\lib\site-packages (from requests) (3.0.4)

# %%
import requests

# %%
data = requests.get("https://www.jumia.com.ng/")

# %%
# data.content

# %%
import requests
url = 'https://rest.coinapi.io/v1/symbols'
headers = {'X-CoinAPI-Key' : '424A42C1-397B-4866-B0E3-19D1691BC592'}
response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# [{'symbol_id': 'BITSTAMP_SPOT_BTC_USD',
#   'exchange_id': 'BITSTAMP',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2011-09-13',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2021-04-17T15:09:58.4010046Z',
#   'data_orderbook_start': '2014-02-24T17:43:05.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:37:54.8477715Z',
#   'data_trade_start': '2011-09-13T13:53:36.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:01.3290000Z',
#   'volume_1hrs': 102.3540185,
#   'volume_1hrs_usd': 6187911.09,
#   'volume_1day': 2983.49991296,
#   'volume_1day_usd': 180370369.98,
#   'volume_1mth': 125726.25340702,
#   'volume_1mth_usd': 7600902129.88,
#   'price': 60411.445,
#   'symbol_id_exchange': 'BTCUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'THEROCKTRADING_SPOT_BTC_EUR',
#   'exchange_id': 'THEROCKTRADING',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'EUR',
#   'data_start': '2011-11-09',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-14T20:05:17.8425642Z',
#   'data_quote_end': '2021-04-17T15:10:17.4280965Z',
#   'data_orderbook_start': '2017-03-14T20:05:17.8425642Z',
#   'data_orderbook_end': '2020-08-05T14:37:04.8352581Z',
#   'data_trade_start': '2011-11-09T14:33:28.0000000Z',
#   'data_trade_end': '2021-04-17T14:56:24.0000000Z',
#   'volume_1hrs': 0.5063,
#   'volume_1hrs_usd': 30608.86,
#   'volume_1day': 18.4884,
#   'volume_1day_usd': 1117734.09,
#   'volume_1mth': 1185.8725,
#   'volume_1mth_usd': 71693067.81,
#   'price': 50818.395,
#   'symbol_id_exchange': 'BTCEUR',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'EUR',
#   'price_precision': 0.01,
#   'size_precision': 0.0001},
#  {'symbol_id': 'VIRWOX_SPOT_BTC_SLL',
#   'exchange_id': 'VIRWOX',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'SLL',
#   'data_start': '2011-04-27',
#   'data_end': '2020-01-06',
#   'data_quote_start': '2017-03-14T20:04:27.0860621Z',
#   'data_quote_end': '2020-01-06T09:52:30.8182707Z',
#   'data_orderbook_start': '2017-03-14T20:04:27.0860621Z',
#   'data_orderbook_end': '2020-01-06T09:52:30.8182707Z',
#   'data_trade_start': '2011-04-27T16:05:09.0000000Z',
#   'data_trade_end': '2020-01-06T09:04:05.0000000Z',
#   'symbol_id_exchange': 'BTC/SLL',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'SLL',
#   'price_precision': 1.0,
#   'size_precision': 0.0001},
#  {'symbol_id': 'BITMARKET_SPOT_BTC_PLN',
#   'exchange_id': 'BITMARKET',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'PLN',
#   'data_start': '2011-04-05',
#   'data_end': '2019-07-08',
#   'data_quote_start': '2017-08-29T15:47:10.0528025Z',
#   'data_quote_end': '2019-07-08T22:04:27.4211942Z',
#   'data_orderbook_start': '2017-08-29T15:47:10.0528025Z',
#   'data_orderbook_end': '2019-07-08T22:04:27.4211942Z',
#   'data_trade_start': '2011-04-05T18:49:48.0000000Z',
#   'data_trade_end': '2019-07-08T22:02:31.0000000Z',
#   'symbol_id_exchange': 'BTCPLN',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'PLN',
#   'price_precision': 0.0001,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITMARKET_SPOT_BTC_EUR',
#   'exchange_id': 'BITMARKET',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'EUR',
#   'data_start': '2011-04-06',
#   'data_end': '2019-07-08',
#   'data_quote_start': '2017-08-29T15:47:11.5022192Z',
#   'data_quote_end': '2019-07-08T22:04:27.3379781Z',
#   'data_orderbook_start': '2017-08-29T15:47:11.5022192Z',
#   'data_orderbook_end': '2019-07-08T22:04:27.3379781Z',
#   'data_trade_start': '2011-04-06T02:17:41.0000000Z',
#   'data_trade_end': '2019-07-08T20:48:48.0000000Z',
#   'symbol_id_exchange': 'BTCEUR',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'EUR',
#   'price_precision': 0.0001,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITFINEX_SPOT_BTC_USD',
#   'exchange_id': 'BITFINEX',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2013-01-14',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2021-04-17T15:09:57.4347542Z',
#   'data_orderbook_start': '2014-02-24T17:43:05.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:37:01.0436148Z',
#   'data_trade_start': '2013-01-14T16:47:23.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:01.2070000Z',
#   'volume_1hrs': 174.67365738,
#   'volume_1hrs_usd': 10560064.73,
#   'volume_1day': 6284.33185064,
#   'volume_1day_usd': 379925354.12,
#   'volume_1mth': 235024.06056385,
#   'volume_1mth_usd': 14208606668.08,
#   'price': 60312.5,
#   'symbol_id_exchange': 'BTCUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BIT2C_SPOT_BTC_NIS',
#   'exchange_id': 'BIT2C',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'NIS',
#   'data_start': '2013-03-15',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2018-01-24T00:42:51.6201442Z',
#   'data_quote_end': '2021-04-17T15:09:59.8060023Z',
#   'data_orderbook_start': '2018-01-24T00:42:51.6201442Z',
#   'data_orderbook_end': '2020-08-05T14:36:11.7904878Z',
#   'data_trade_start': '2013-03-15T12:48:43.0000000Z',
#   'data_trade_end': '2020-06-25T13:09:04.0000000Z',
#   'price': 204149.925,
#   'symbol_id_exchange': 'BtcNis',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'NIS',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITFINEX_SPOT_LTC_USD',
#   'exchange_id': 'BITFINEX',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2013-05-19',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-04-20T15:29:33.5430000Z',
#   'data_quote_end': '2021-04-17T15:09:57.4027282Z',
#   'data_orderbook_start': '2014-04-20T15:29:33.5430000Z',
#   'data_orderbook_end': '2020-08-05T14:37:01.0038865Z',
#   'data_trade_start': '2013-05-19T15:23:45.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:05.4050000Z',
#   'volume_1hrs': 9326.34756827,
#   'volume_1hrs_usd': 2896412.64,
#   'volume_1day': 342480.36844002,
#   'volume_1day_usd': 106361516.29,
#   'volume_1mth': 3103901.83792431,
#   'volume_1mth_usd': 963955123.59,
#   'price': 309.7,
#   'symbol_id_exchange': 'LTCUSD',
#   'asset_id_base_exchange': 'LTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITFINEX_SPOT_LTC_BTC',
#   'exchange_id': 'BITFINEX',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'BTC',
#   'data_start': '2013-05-23',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-04-20T15:29:33.5470000Z',
#   'data_quote_end': '2021-04-17T15:09:57.4076650Z',
#   'data_orderbook_start': '2014-04-20T15:29:33.5470000Z',
#   'data_orderbook_end': '2020-08-05T14:37:01.0491453Z',
#   'data_trade_start': '2013-05-23T12:08:10.0000000Z',
#   'data_trade_end': '2021-04-17T15:11:49.4100000Z',
#   'volume_1hrs': 162.70063339,
#   'volume_1hrs_usd': 50528.69,
#   'volume_1day': 38538.43250626,
#   'volume_1day_usd': 11968587.09,
#   'volume_1mth': 315855.20707902,
#   'volume_1mth_usd': 98092742.97,
#   'price': 0.0051334,
#   'symbol_id_exchange': 'LTCBTC',
#   'asset_id_base_exchange': 'LTC',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-07,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BTCCHINA_SPOT_BTC_CNY',
#   'exchange_id': 'BTCCHINA',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'CNY',
#   'data_start': '2011-06-13',
#   'data_end': '2019-02-06',
#   'data_quote_start': '2015-03-29T04:20:18.0000000Z',
#   'data_quote_end': '2019-02-06T15:38:24.2104836Z',
#   'data_orderbook_start': '2015-03-29T04:20:18.0000000Z',
#   'data_orderbook_end': '2019-02-06T15:38:24.2104836Z',
#   'data_trade_start': '2011-06-13T05:13:24.0000000Z',
#   'data_trade_end': '2018-03-09T21:55:08.0000000Z',
#   'symbol_id_exchange': 'BTCCNY',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'CNY',
#   'price_precision': 0.01,
#   'size_precision': 0.0001},
#  {'symbol_id': 'ITBIT_SPOT_BTC_USD',
#   'exchange_id': 'ITBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2013-08-25',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-05-26T18:24:30.1470000Z',
#   'data_quote_end': '2021-04-17T15:10:07.2829772Z',
#   'data_orderbook_start': '2015-05-26T18:24:30.1470000Z',
#   'data_orderbook_end': '2020-08-05T14:38:00.7082850Z',
#   'data_trade_start': '2013-08-25T00:21:44.0000000Z',
#   'data_trade_end': '2021-04-17T15:09:40.1600000Z',
#   'volume_1hrs': 9.98656772,
#   'volume_1hrs_usd': 603747.6,
#   'volume_1day': 280.26110686,
#   'volume_1day_usd': 16943456.01,
#   'volume_1mth': 11565.98456511,
#   'volume_1mth_usd': 699232772.26,
#   'price': 60481.0,
#   'symbol_id_exchange': 'XBTUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KORBIT_SPOT_BTC_KRW',
#   'exchange_id': 'KORBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'KRW',
#   'data_start': '2013-09-03',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:53:39.4192811Z',
#   'data_quote_end': '2021-04-17T15:10:14.3367466Z',
#   'data_orderbook_start': '2017-03-18T22:53:39.4192811Z',
#   'data_orderbook_end': '2020-08-05T14:37:11.3968034Z',
#   'data_trade_start': '2013-09-03T06:31:37.0000000Z',
#   'data_trade_end': '2019-10-01T17:25:00.7870000Z',
#   'price': 77985250,
#   'symbol_id_exchange': 'BTC_KRW',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'KRW',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'ITBIT_SPOT_BTC_EUR',
#   'exchange_id': 'ITBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'EUR',
#   'data_start': '2013-11-17',
#   'data_end': '2021-04-08',
#   'data_quote_start': '2015-05-26T18:24:28.9330000Z',
#   'data_quote_end': '2021-04-08T15:16:40.5281133Z',
#   'data_orderbook_start': '2015-05-26T18:24:28.9330000Z',
#   'data_orderbook_end': '2020-08-05T14:34:18.7311899Z',
#   'data_trade_start': '2013-11-17T17:14:09.0000000Z',
#   'data_trade_end': '2021-03-25T08:08:28.2670000Z',
#   'volume_1mth': 0.00061702,
#   'volume_1mth_usd': 37.3,
#   'symbol_id_exchange': 'XBTEUR',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'EUR',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'ITBIT_SPOT_BTC_SGD',
#   'exchange_id': 'ITBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'SGD',
#   'data_start': '2013-11-18',
#   'data_end': '2021-04-08',
#   'data_quote_start': '2015-05-26T18:24:30.2530000Z',
#   'data_quote_end': '2021-04-08T12:29:37.5374547Z',
#   'data_orderbook_start': '2015-05-26T18:24:30.2530000Z',
#   'data_orderbook_end': '2020-08-05T11:52:58.9517484Z',
#   'data_trade_start': '2013-11-18T01:16:14.0000000Z',
#   'data_trade_end': '2021-02-14T10:11:42.0370000Z',
#   'symbol_id_exchange': 'XBTSGD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'SGD',
#   'price_precision': 0.01,
#   'size_precision': 0.0001},
#  {'symbol_id': 'HITBTC_SPOT_BTC_USDT',
#   'exchange_id': 'HITBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USDT',
#   'data_start': '2013-12-27',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:53:48.7935165Z',
#   'data_quote_end': '2021-04-17T15:09:57.1611567Z',
#   'data_orderbook_start': '2017-03-18T22:53:48.7935165Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.3001987Z',
#   'data_trade_start': '2013-12-27T08:23:37.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:00.0000000Z',
#   'volume_1hrs': 32.42895,
#   'volume_1hrs_usd': 1960523.51,
#   'volume_1day': 16177.00589,
#   'volume_1day_usd': 977996521.75,
#   'volume_1mth': 769026.67551,
#   'volume_1mth_usd': 46492250722.62,
#   'price': 60336.18,
#   'symbol_id_exchange': 'BTCUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 1e-05},
#  {'symbol_id': 'KRAKEN_SPOT_BTC_USD',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2014-01-07',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-07-31T13:05:46.0000000Z',
#   'data_quote_end': '2021-04-17T15:09:57.2371867Z',
#   'data_orderbook_start': '2014-07-31T13:05:46.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.0635914Z',
#   'data_trade_start': '2014-01-07T18:18:17.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:06.3250000Z',
#   'volume_1hrs': 186.66695342,
#   'volume_1hrs_usd': 11285131.03,
#   'volume_1day': 3190.28266584,
#   'volume_1day_usd': 192871621.1,
#   'volume_1mth': 133360.54465166,
#   'volume_1mth_usd': 8062440583.53,
#   'price': 60430.05,
#   'symbol_id_exchange': 'BTC/USD',
#   'asset_id_base_exchange': 'XXBT',
#   'asset_id_quote_exchange': 'ZUSD',
#   'price_precision': 0.1,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_BTC_EUR',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'EUR',
#   'data_start': '2014-01-08',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-07-31T13:05:46.0000000Z',
#   'data_quote_end': '2021-04-17T15:09:59.6019344Z',
#   'data_orderbook_start': '2014-07-31T13:05:46.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.1181555Z',
#   'data_trade_start': '2014-01-08T09:26:29.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:06.0660000Z',
#   'volume_1hrs': 95.94005366,
#   'volume_1hrs_usd': 5800148.64,
#   'volume_1day': 2482.43399774,
#   'volume_1day_usd': 150077945.93,
#   'volume_1mth': 109806.00780221,
#   'volume_1mth_usd': 6638428299.26,
#   'price': 50683.55,
#   'symbol_id_exchange': 'XBT/EUR',
#   'asset_id_base_exchange': 'XXBT',
#   'asset_id_quote_exchange': 'ZEUR',
#   'price_precision': 0.1,
#   'size_precision': 1e-08},
#  {'symbol_id': 'LAKEBTC_SPOT_BTC_USD',
#   'exchange_id': 'LAKEBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2014-03-01',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:53:40.7300076Z',
#   'data_quote_end': '2021-04-17T15:10:10.6335972Z',
#   'data_orderbook_start': '2017-03-18T22:53:40.7300076Z',
#   'data_orderbook_end': '2020-08-05T14:37:29.7111999Z',
#   'data_trade_start': '2014-03-01T12:01:39.0000000Z',
#   'data_trade_end': '2021-04-17T14:57:17.0000000Z',
#   'volume_1hrs': 1.025798,
#   'volume_1hrs_usd': 62015.61,
#   'volume_1day': 29.656001,
#   'volume_1day_usd': 1792882.19,
#   'volume_1mth': 991.186847,
#   'volume_1mth_usd': 59923158.55,
#   'price': 60770.54,
#   'symbol_id_exchange': 'BTCUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 0.0001},
#  {'symbol_id': 'BITBAY_SPOT_BTC_PLN',
#   'exchange_id': 'BITBAY',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'PLN',
#   'data_start': '2014-03-29',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-08-29T15:47:11.7695899Z',
#   'data_quote_end': '2021-04-17T15:10:03.4680000Z',
#   'data_orderbook_start': '2017-08-29T15:47:11.7695899Z',
#   'data_orderbook_end': '2020-08-05T14:37:37.1750000Z',
#   'data_trade_start': '2014-03-29T12:36:43.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:27.6920000Z',
#   'volume_1hrs': 37.14851156,
#   'volume_1hrs_usd': 2245849.16,
#   'volume_1day': 935.25904883,
#   'volume_1day_usd': 56541989.47,
#   'volume_1mth': 34248.860768,
#   'volume_1mth_usd': 2070547969.92,
#   'price': 232120.955,
#   'symbol_id_exchange': 'BTCPLN',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'PLN',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITBAY_SPOT_LTC_PLN',
#   'exchange_id': 'BITBAY',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'PLN',
#   'data_start': '2014-04-04',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-08-29T15:47:16.3040447Z',
#   'data_quote_end': '2021-04-17T15:10:10.9500000Z',
#   'data_orderbook_start': '2017-08-29T15:47:16.3040447Z',
#   'data_orderbook_end': '2020-08-05T14:37:41.4110000Z',
#   'data_trade_start': '2014-04-04T10:06:52.0000000Z',
#   'data_trade_end': '2021-04-17T14:57:44.9690000Z',
#   'volume_1hrs': 188.5868648,
#   'volume_1hrs_usd': 58567.98,
#   'volume_1day': 8891.93527873,
#   'volume_1day_usd': 2761500.53,
#   'volume_1mth': 101347.90525916,
#   'volume_1mth_usd': 31474846.06,
#   'price': 1179.65,
#   'symbol_id_exchange': 'LTCPLN',
#   'asset_id_base_exchange': 'LTC',
#   'asset_id_quote_exchange': 'PLN',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITBAY_SPOT_LTC_BTC',
#   'exchange_id': 'BITBAY',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'BTC',
#   'data_start': '2014-04-11',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2018-01-19T18:59:42.3101741Z',
#   'data_quote_end': '2021-04-17T15:09:57.9110000Z',
#   'data_orderbook_start': '2018-01-19T18:59:42.3101741Z',
#   'data_orderbook_end': '2020-08-05T14:37:18.1030000Z',
#   'data_trade_start': '2014-04-11T12:52:52.0000000Z',
#   'data_trade_end': '2021-04-17T15:00:37.1870000Z',
#   'volume_1hrs': 8.12603253,
#   'volume_1hrs_usd': 2523.64,
#   'volume_1day': 524.51648487,
#   'volume_1day_usd': 162895.08,
#   'volume_1mth': 5695.21661939,
#   'volume_1mth_usd': 1768719.99,
#   'price': 0.004966365,
#   'symbol_id_exchange': 'LTCBTC',
#   'asset_id_base_exchange': 'LTC',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITBAY_SPOT_BTC_USD',
#   'exchange_id': 'BITBAY',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2014-05-16',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-08-29T15:47:13.8206779Z',
#   'data_quote_end': '2021-04-17T15:01:03.5070000Z',
#   'data_orderbook_start': '2017-08-29T15:47:13.8206779Z',
#   'data_orderbook_end': '2020-08-05T13:59:57.7440000Z',
#   'data_trade_start': '2014-05-16T08:46:42.0000000Z',
#   'data_trade_end': '2021-04-17T15:01:03.5070000Z',
#   'volume_1hrs': 0.07381708,
#   'volume_1hrs_usd': 4462.68,
#   'volume_1day': 0.07549511,
#   'volume_1day_usd': 4564.13,
#   'volume_1mth': 5.89453154,
#   'volume_1mth_usd': 356359.6,
#   'price': 62609.92,
#   'symbol_id_exchange': 'BTCUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_LTC_USD',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2014-06-02',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-07-31T13:05:46.0000000Z',
#   'data_quote_end': '2021-04-17T15:09:57.3715440Z',
#   'data_orderbook_start': '2014-07-31T13:05:46.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:37:19.6310250Z',
#   'data_trade_start': '2014-06-02T05:21:37.7270000Z',
#   'data_trade_end': '2021-04-17T15:10:11.8140000Z',
#   'volume_1hrs': 9051.41371332,
#   'volume_1hrs_usd': 2811028.53,
#   'volume_1day': 239640.17745854,
#   'volume_1day_usd': 74423222.43,
#   'volume_1mth': 2328405.44465943,
#   'volume_1mth_usd': 723115122.64,
#   'price': 310.24,
#   'symbol_id_exchange': 'LTC/USD',
#   'asset_id_base_exchange': 'XLTC',
#   'asset_id_quote_exchange': 'ZUSD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_LTC_EUR',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'EUR',
#   'data_start': '2014-07-30',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-07-31T13:05:46.0000000Z',
#   'data_quote_end': '2021-04-17T15:09:57.3470998Z',
#   'data_orderbook_start': '2014-07-31T13:05:46.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:37:19.1052637Z',
#   'data_trade_start': '2014-07-30T07:37:35.5630000Z',
#   'data_trade_end': '2021-04-17T15:10:15.6780000Z',
#   'volume_1hrs': 1718.17129081,
#   'volume_1hrs_usd': 533599.36,
#   'volume_1day': 117197.45343866,
#   'volume_1day_usd': 36397119.37,
#   'volume_1mth': 1403578.93467434,
#   'volume_1mth_usd': 435898806.11,
#   'price': 260.165,
#   'symbol_id_exchange': 'LTC/EUR',
#   'asset_id_base_exchange': 'XLTC',
#   'asset_id_quote_exchange': 'ZEUR',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'FYBSG_SPOT_BTC_SGD',
#   'exchange_id': 'FYBSG',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'SGD',
#   'data_start': '2013-01-07',
#   'data_end': '2019-08-28',
#   'data_quote_start': '2018-01-24T00:21:35.8644461Z',
#   'data_quote_end': '2019-08-28T00:23:39.4396719Z',
#   'data_orderbook_start': '2018-01-24T00:21:35.8644461Z',
#   'data_orderbook_end': '2019-08-28T00:23:39.4396719Z',
#   'data_trade_start': '2013-01-07T06:17:04.0000000Z',
#   'data_trade_end': '2018-06-28T07:22:05.0000000Z',
#   'symbol_id_exchange': 'BTC/SGD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'SGD',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'FYBSG_SPOT_BTC_SEK',
#   'exchange_id': 'FYBSG',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'SEK',
#   'data_start': '2013-01-07',
#   'data_end': '2019-08-28',
#   'data_quote_start': '2018-01-24T00:22:06.9288316Z',
#   'data_quote_end': '2019-08-28T00:23:36.9300000Z',
#   'data_orderbook_start': '2018-01-24T00:22:06.9288316Z',
#   'data_orderbook_end': '2019-08-28T00:23:36.9300000Z',
#   'data_trade_start': '2013-01-07T06:17:04.0000000Z',
#   'data_trade_end': '2018-06-28T07:22:05.0000000Z',
#   'symbol_id_exchange': 'BTC/SEK',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'SEK',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BTC-E_SPOT_BTC_USD',
#   'exchange_id': 'BTC-E',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2011-08-14',
#   'data_end': '2018-03-09',
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2018-03-09T21:51:11.8160000Z',
#   'data_orderbook_start': '2014-02-24T17:43:05.0000000Z',
#   'data_orderbook_end': '2018-03-09T21:51:11.8160000Z',
#   'data_trade_start': '2011-08-14T14:14:40.0000000Z',
#   'data_trade_end': '2017-07-25T10:48:12.0000000Z',
#   'symbol_id_exchange': 'btc_usd',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD'},
#  {'symbol_id': 'VBTC_SPOT_BTC_VEF',
#   'exchange_id': 'VBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'VEF',
#   'data_start': '2014-08-15',
#   'data_end': '2021-02-08',
#   'data_quote_start': '2017-03-14T20:05:02.7389439Z',
#   'data_quote_end': '2021-02-08T10:04:20.5895838Z',
#   'data_orderbook_start': '2017-03-14T20:05:02.7389439Z',
#   'data_orderbook_end': '2020-08-05T11:57:26.7892745Z',
#   'data_trade_start': '2014-08-15T17:27:03.0000000Z',
#   'data_trade_end': '2014-10-17T16:44:10.0000000Z',
#   'symbol_id_exchange': 'SURBITCOINV',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'VEF',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'SURBITCOIN_SPOT_BTC_VEF',
#   'exchange_id': 'SURBITCOIN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'VEF',
#   'data_start': '2014-08-15',
#   'data_end': '2021-02-08',
#   'data_quote_start': '2017-03-18T22:53:39.8859603Z',
#   'data_quote_end': '2021-02-08T10:03:19.7627517Z',
#   'data_orderbook_start': '2017-03-18T22:53:39.8859603Z',
#   'data_orderbook_end': '2020-08-05T11:57:02.3602704Z',
#   'data_trade_start': '2014-08-15T17:27:03.0000000Z',
#   'data_trade_end': '2015-02-19T16:03:23.0000000Z',
#   'symbol_id_exchange': 'VEF',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'VEF',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_BTC_GBP',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'GBP',
#   'data_start': '2014-11-14',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-11-14T01:42:12.5570000Z',
#   'data_quote_end': '2021-04-17T15:10:00.9697726Z',
#   'data_orderbook_start': '2014-11-14T01:42:12.5570000Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.0871913Z',
#   'data_trade_start': '2016-10-17T16:03:28.1660000Z',
#   'data_trade_end': '2021-04-17T15:10:47.3260000Z',
#   'volume_1hrs': 3.33998493,
#   'volume_1hrs_usd': 201922.02,
#   'volume_1day': 98.38526394,
#   'volume_1day_usd': 5947976.19,
#   'volume_1mth': 4916.45610626,
#   'volume_1mth_usd': 297229104.32,
#   'price': 43986.0,
#   'symbol_id_exchange': 'BTC/GBP',
#   'asset_id_base_exchange': 'XXBT',
#   'asset_id_quote_exchange': 'ZGBP',
#   'price_precision': 0.1,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_BTC_JPY',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'JPY',
#   'data_start': '2014-11-14',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2014-11-14T01:42:12.5570000Z',
#   'data_quote_end': '2021-04-17T15:09:59.3650695Z',
#   'data_orderbook_start': '2014-11-14T01:42:12.5570000Z',
#   'data_orderbook_end': '2020-08-05T14:37:17.0025009Z',
#   'data_trade_start': '2016-10-17T13:33:19.1400000Z',
#   'data_trade_end': '2021-04-17T15:04:40.4570000Z',
#   'volume_1hrs': 0.016,
#   'volume_1hrs_usd': 967.3,
#   'volume_1day': 1.48690202,
#   'volume_1day_usd': 89892.1,
#   'volume_1mth': 97.62597662,
#   'volume_1mth_usd': 5902072.75,
#   'price': 6585206.0,
#   'symbol_id_exchange': 'BTC/JPY',
#   'asset_id_base_exchange': 'XXBT',
#   'asset_id_quote_exchange': 'ZJPY',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'VBTC_SPOT_BTC_PKR',
#   'exchange_id': 'VBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'PKR',
#   'data_start': '2014-10-14',
#   'data_end': '2021-02-16',
#   'data_quote_start': '2017-03-14T20:05:08.4199204Z',
#   'data_quote_end': '2021-02-16T14:34:18.9804859Z',
#   'data_orderbook_start': '2017-03-14T20:05:08.4199204Z',
#   'data_orderbook_end': '2020-07-28T15:22:52.3290623Z',
#   'data_trade_start': '2014-10-14T04:46:00.0000000Z',
#   'data_trade_end': '2015-10-15T13:19:33.0000000Z',
#   'symbol_id_exchange': 'URDUBIT',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'PKR',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_NAV_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'NAV',
#   'asset_id_quote': 'BTC',
#   'data_start': '2015-01-06',
#   'data_end': '2021-04-12',
#   'data_quote_start': '2017-03-19T01:18:17.1450725Z',
#   'data_quote_end': '2021-04-12T15:48:17.8167220Z',
#   'data_orderbook_start': '2017-03-19T01:18:17.1450725Z',
#   'data_orderbook_end': '2019-08-02T04:37:57.5775000Z',
#   'data_trade_start': '2015-01-06T19:51:51.0000000Z',
#   'data_trade_end': '2015-03-31T23:54:34.0000000Z',
#   'symbol_id_exchange': 'NAV_BTC',
#   'asset_id_base_exchange': 'NAV',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'COINBASE_SPOT_BTC_USD',
#   'exchange_id': 'COINBASE',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2015-01-14',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-05-17T00:51:36.2870000Z',
#   'data_quote_end': '2021-04-17T15:12:26.7144750Z',
#   'data_orderbook_start': '2015-05-17T00:51:36.2870000Z',
#   'data_orderbook_end': '2020-08-05T14:37:54.0490500Z',
#   'data_trade_start': '2015-01-14T16:07:05.0000000Z',
#   'data_trade_end': '2021-04-17T14:59:02.6092500Z',
#   'volume_1hrs': 502.75498021,
#   'volume_1hrs_usd': 30394538.1,
#   'volume_1day': 12728.00994706,
#   'volume_1day_usd': 769484139.5,
#   'volume_1mth': 454590.75065324,
#   'volume_1mth_usd': 27482723068.79,
#   'price': 60414.745,
#   'symbol_id_exchange': 'BTC-USD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITBAY_SPOT_LTC_USD',
#   'exchange_id': 'BITBAY',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2015-01-15',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-08-29T15:47:16.0660582Z',
#   'data_quote_end': '2021-04-17T15:01:04.6780000Z',
#   'data_orderbook_start': '2017-08-29T15:47:16.0660582Z',
#   'data_orderbook_end': '2020-08-05T14:30:48.7060000Z',
#   'data_trade_start': '2015-01-15T03:32:12.0000000Z',
#   'data_trade_end': '2021-04-17T13:47:09.8730000Z',
#   'volume_1day': 57.84569468,
#   'volume_1day_usd': 17964.7,
#   'volume_1mth': 238.71137918,
#   'volume_1mth_usd': 74134.77,
#   'price': 313.955,
#   'symbol_id_exchange': 'LTCUSD',
#   'asset_id_base_exchange': 'LTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_RICE_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'RICE',
#   'asset_id_quote': 'BTC',
#   'data_start': '2015-01-30',
#   'data_end': '2021-04-15',
#   'data_quote_start': '2017-03-18T22:58:18.3396481Z',
#   'data_quote_end': '2021-04-15T12:12:43.3452479Z',
#   'data_orderbook_start': '2017-03-18T22:58:18.3396481Z',
#   'data_orderbook_end': '2019-08-02T17:37:02.7490009Z',
#   'data_trade_start': '2015-01-30T18:45:25.0000000Z',
#   'data_trade_end': '2021-04-15T11:41:16.0000000Z',
#   'volume_1mth': 1242.00485152,
#   'volume_1mth_usd': 1267.63,
#   'symbol_id_exchange': 'RICE_BTC',
#   'asset_id_base_exchange': 'rice',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'OKCOINUSD_SPOT_LTC_USD',
#   'exchange_id': 'OKCOINUSD',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2015-02-14',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-02-15T12:53:46.7170000Z',
#   'data_quote_end': '2021-04-17T15:09:58.9190000Z',
#   'data_orderbook_start': '2015-02-15T12:53:46.7170000Z',
#   'data_orderbook_end': '2020-07-21T08:30:00.1490000Z',
#   'data_trade_start': '2015-02-14T16:15:05.7070000Z',
#   'data_trade_end': '2021-04-17T15:11:13.6160000Z',
#   'volume_1hrs': 385.9267,
#   'volume_1hrs_usd': 119854.31,
#   'volume_1day': 11398.8579,
#   'volume_1day_usd': 3540056.37,
#   'volume_1mth': 104075.3645,
#   'volume_1mth_usd': 32321892.28,
#   'price': 310.285,
#   'symbol_id_exchange': 'ltc_usd',
#   'asset_id_base_exchange': 'LTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 0.0001},
#  {'symbol_id': 'OKCOINUSD_SPOT_BTC_USD',
#   'exchange_id': 'OKCOINUSD',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2015-02-14',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-02-15T12:53:46.6330000Z',
#   'data_quote_end': '2021-04-17T15:09:57.9610000Z',
#   'data_orderbook_start': '2015-02-15T12:53:46.6330000Z',
#   'data_orderbook_end': '2020-07-21T08:40:29.7790000Z',
#   'data_trade_start': '2015-02-14T16:15:05.5900000Z',
#   'data_trade_end': '2021-04-17T15:10:50.5700000Z',
#   'volume_1hrs': 22.5967,
#   'volume_1hrs_usd': 1366105.33,
#   'volume_1day': 486.3223,
#   'volume_1day_usd': 29401084.54,
#   'volume_1mth': 19822.1786,
#   'volume_1mth_usd': 1198368960.0,
#   'price': 60415.97,
#   'symbol_id_exchange': 'btc_usd',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 0.0001},
#  {'symbol_id': 'VBTC_SPOT_BTC_BRL',
#   'exchange_id': 'VBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'BRL',
#   'data_start': '2014-12-11',
#   'data_end': '2021-02-08',
#   'data_quote_start': '2017-03-14T20:05:02.3943786Z',
#   'data_quote_end': '2021-02-08T10:04:21.2406039Z',
#   'data_orderbook_start': '2017-03-14T20:05:02.3943786Z',
#   'data_orderbook_end': '2020-08-05T11:57:27.0169899Z',
#   'data_trade_start': '2014-12-11T10:31:07.0000000Z',
#   'data_trade_end': '2015-02-19T16:03:23.0000000Z',
#   'symbol_id_exchange': 'FOXBIT',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'BRL',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'FOXBIT_SPOT_BTC_BRL',
#   'exchange_id': 'FOXBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'BRL',
#   'data_start': '2014-12-11',
#   'data_end': '2021-02-08',
#   'data_quote_start': '2017-03-18T22:53:42.1600307Z',
#   'data_quote_end': '2021-02-08T10:02:11.6417623Z',
#   'data_orderbook_start': '2017-03-18T22:53:42.1600307Z',
#   'data_orderbook_end': '2020-08-05T11:50:56.9808233Z',
#   'data_trade_start': '2014-12-11T10:31:07.0000000Z',
#   'data_trade_end': '2014-12-14T14:07:14.0000000Z',
#   'symbol_id_exchange': 'BRL',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'BRL',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'CHILEBIT_SPOT_BTC_CLP',
#   'exchange_id': 'CHILEBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'CLP',
#   'data_start': '2014-12-12',
#   'data_end': '2021-02-09',
#   'data_quote_start': '2017-03-18T22:53:41.7026460Z',
#   'data_quote_end': '2021-02-09T15:47:03.5138958Z',
#   'data_orderbook_start': '2017-03-18T22:53:41.7026460Z',
#   'data_orderbook_end': '2020-08-05T11:47:48.3514633Z',
#   'data_trade_start': '2014-12-12T16:36:44.0000000Z',
#   'data_trade_end': '2015-04-29T17:27:49.0000000Z',
#   'symbol_id_exchange': 'CLP',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'CLP',
#   'price_precision': 1.0,
#   'size_precision': 1e-07},
#  {'symbol_id': 'VBTC_SPOT_BTC_CLP',
#   'exchange_id': 'VBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'CLP',
#   'data_start': '2014-12-12',
#   'data_end': '2021-02-08',
#   'data_quote_start': '2017-03-14T20:05:03.2582137Z',
#   'data_quote_end': '2021-02-08T10:04:21.7577770Z',
#   'data_orderbook_start': '2017-03-14T20:05:03.2582137Z',
#   'data_orderbook_end': '2020-08-05T11:57:26.6367814Z',
#   'data_trade_start': '2014-12-12T16:36:44.0000000Z',
#   'data_trade_end': '2018-03-09T21:58:24.8810000Z',
#   'symbol_id_exchange': 'SURBITCOINC',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'CLP',
#   'price_precision': 1.0,
#   'size_precision': 1e-07},
#  {'symbol_id': 'THEROCKTRADING_SPOT_BTC_USD',
#   'exchange_id': 'THEROCKTRADING',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2011-11-12',
#   'data_end': '2018-01-03',
#   'data_quote_start': '2017-03-14T20:07:11.9706952Z',
#   'data_quote_end': '2018-01-03T14:06:10.5868431Z',
#   'data_orderbook_start': '2017-03-14T20:07:11.9706952Z',
#   'data_orderbook_end': '2018-01-03T14:06:10.5868431Z',
#   'data_trade_start': '2011-11-12T06:54:45.0000000Z',
#   'data_trade_end': '2018-01-03T02:46:46.0000000Z',
#   'symbol_id_exchange': 'BTCUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD'},
#  {'symbol_id': 'YOBIT_SPOT_ETCO_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETCO',
#   'asset_id_quote': 'BTC',
#   'data_start': '2015-02-20',
#   'data_end': '2021-04-09',
#   'data_quote_start': '2017-03-18T23:41:18.7823242Z',
#   'data_quote_end': '2021-04-09T22:00:22.6063160Z',
#   'data_orderbook_start': '2017-03-18T23:41:18.7823242Z',
#   'data_orderbook_end': '2019-08-01T23:35:41.4041371Z',
#   'data_trade_start': '2015-02-20T11:19:25.0000000Z',
#   'data_trade_end': '2018-03-17T18:06:53.0000000Z',
#   'symbol_id_exchange': 'ETCO_BTC',
#   'asset_id_base_exchange': 'etco',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 0.0001},
#  {'symbol_id': 'FYBSE_SPOT_BTC_SEK',
#   'exchange_id': 'FYBSE',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'SEK',
#   'data_start': '2013-07-15',
#   'data_end': '2019-08-28',
#   'data_quote_start': '2018-01-24T00:21:52.7701638Z',
#   'data_quote_end': '2019-08-28T13:11:39.4081373Z',
#   'data_orderbook_start': '2018-01-24T00:21:52.7701638Z',
#   'data_orderbook_end': '2019-08-28T13:11:39.4081373Z',
#   'data_trade_start': '2013-07-15T20:40:11.0000000Z',
#   'data_trade_end': '2018-02-26T14:50:15.0000000Z',
#   'symbol_id_exchange': 'BTC/SEK',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'SEK',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITBAY_SPOT_BTC_EUR',
#   'exchange_id': 'BITBAY',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'EUR',
#   'data_start': '2015-03-17',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-08-29T15:47:11.6744609Z',
#   'data_quote_end': '2021-04-17T15:09:57.5620000Z',
#   'data_orderbook_start': '2017-08-29T15:47:11.6744609Z',
#   'data_orderbook_end': '2020-08-05T14:37:41.0610000Z',
#   'data_trade_start': '2015-03-17T17:28:13.0000000Z',
#   'data_trade_end': '2021-04-17T15:06:34.5290000Z',
#   'volume_1hrs': 0.08484274,
#   'volume_1hrs_usd': 5129.25,
#   'volume_1day': 2.00800308,
#   'volume_1day_usd': 121395.77,
#   'volume_1mth': 365.28940995,
#   'volume_1mth_usd': 22083924.23,
#   'price': 50967.11,
#   'symbol_id_exchange': 'BTCEUR',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'EUR',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'COINBASE_SPOT_BTC_GBP',
#   'exchange_id': 'COINBASE',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'GBP',
#   'data_start': '2015-04-21',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-05-17T00:51:35.6000000Z',
#   'data_quote_end': '2021-04-17T15:02:00.1592920Z',
#   'data_orderbook_start': '2015-05-17T00:51:35.6000000Z',
#   'data_orderbook_end': '2020-08-05T14:37:53.5446280Z',
#   'data_trade_start': '2015-04-21T22:22:41.0000000Z',
#   'data_trade_end': '2021-04-17T15:09:34.1643190Z',
#   'volume_1hrs': 29.47756016,
#   'volume_1hrs_usd': 1782094.38,
#   'volume_1day': 604.30736014,
#   'volume_1day_usd': 36533985.36,
#   'volume_1mth': 24836.90606149,
#   'volume_1mth_usd': 1501539154.05,
#   'price': 43955.46,
#   'symbol_id_exchange': 'BTC-GBP',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'GBP',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'COINBASE_SPOT_BTC_EUR',
#   'exchange_id': 'COINBASE',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'EUR',
#   'data_start': '2015-04-23',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-05-17T00:51:32.6370000Z',
#   'data_quote_end': '2021-04-17T15:00:41.7178850Z',
#   'data_orderbook_start': '2015-05-17T00:51:32.6370000Z',
#   'data_orderbook_end': '2020-08-05T14:37:53.6935910Z',
#   'data_trade_start': '2015-04-23T01:42:34.0000000Z',
#   'data_trade_end': '2021-04-17T15:11:30.7382550Z',
#   'volume_1hrs': 44.07849136,
#   'volume_1hrs_usd': 2664807.79,
#   'volume_1day': 934.40181396,
#   'volume_1day_usd': 56490164.51,
#   'volume_1mth': 46242.63940069,
#   'volume_1mth_usd': 2795643445.88,
#   'price': 50670.84,
#   'symbol_id_exchange': 'BTC-EUR',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'EUR',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_BTC_CAD',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'CAD',
#   'data_start': '2015-07-22',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-07-22T10:25:35.9270000Z',
#   'data_quote_end': '2021-04-17T15:09:59.4920207Z',
#   'data_orderbook_start': '2015-07-22T10:25:35.9270000Z',
#   'data_orderbook_end': '2020-08-05T14:37:19.3269631Z',
#   'data_trade_start': '2016-03-09T05:18:09.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:09.9160000Z',
#   'volume_1hrs': 3.23723529,
#   'volume_1hrs_usd': 195710.19,
#   'volume_1day': 62.75926557,
#   'volume_1day_usd': 3794172.04,
#   'volume_1mth': 2138.28615208,
#   'volume_1mth_usd': 129272155.39,
#   'price': 75858.15,
#   'symbol_id_exchange': 'XBT/CAD',
#   'asset_id_base_exchange': 'XXBT',
#   'asset_id_quote_exchange': 'ZCAD',
#   'price_precision': 0.1,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_ETH_CAD',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'CAD',
#   'data_start': '2015-08-10',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-08-10T13:45:07.8130000Z',
#   'data_quote_end': '2021-04-17T15:09:58.3024618Z',
#   'data_orderbook_start': '2015-08-10T13:45:07.8130000Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.0224883Z',
#   'data_trade_start': '2016-10-17T18:13:54.8330000Z',
#   'data_trade_end': '2021-04-17T15:12:40.3420000Z',
#   'volume_1hrs': 8.47344821,
#   'volume_1hrs_usd': 20057.36,
#   'volume_1day': 526.46341235,
#   'volume_1day_usd': 1246182.9,
#   'volume_1mth': 19953.08490424,
#   'volume_1mth_usd': 47230619.88,
#   'price': 2972.415,
#   'symbol_id_exchange': 'ETH/CAD',
#   'asset_id_base_exchange': 'XETH',
#   'asset_id_quote_exchange': 'ZCAD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_ETH_BTC',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'BTC',
#   'data_start': '2015-08-10',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-08-10T13:45:07.8130000Z',
#   'data_quote_end': '2021-04-17T15:09:58.2088378Z',
#   'data_orderbook_start': '2015-08-10T13:45:07.8130000Z',
#   'data_orderbook_end': '2020-08-05T14:37:19.3945036Z',
#   'data_trade_start': '2016-10-17T13:34:45.7380000Z',
#   'data_trade_end': '2021-04-17T15:11:12.0950000Z',
#   'volume_1hrs': 564.40843819,
#   'volume_1hrs_usd': 1336001.95,
#   'volume_1day': 15034.73279136,
#   'volume_1day_usd': 35588469.3,
#   'volume_1mth': 343055.87662644,
#   'volume_1mth_usd': 812041936.59,
#   'price': 0.039115,
#   'symbol_id_exchange': 'ETH/XBT',
#   'asset_id_base_exchange': 'XETH',
#   'asset_id_quote_exchange': 'XXBT',
#   'price_precision': 1e-05,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_ETH_EUR',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'EUR',
#   'data_start': '2015-08-10',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-08-10T13:45:07.8130000Z',
#   'data_quote_end': '2021-04-17T15:09:57.7380347Z',
#   'data_orderbook_start': '2015-08-10T13:45:07.8130000Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.1134164Z',
#   'data_trade_start': '2016-10-17T13:41:10.5310000Z',
#   'data_trade_end': '2021-04-17T15:10:10.8260000Z',
#   'volume_1hrs': 1274.71930105,
#   'volume_1hrs_usd': 3017367.14,
#   'volume_1day': 23910.46660859,
#   'volume_1day_usd': 56598073.18,
#   'volume_1mth': 948618.59781998,
#   'volume_1mth_usd': 2245459517.67,
#   'price': 1981.605,
#   'symbol_id_exchange': 'ETH/EUR',
#   'asset_id_base_exchange': 'XETH',
#   'asset_id_quote_exchange': 'ZEUR',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_ETH_USD',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'USD',
#   'data_start': '2015-08-10',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-08-10T13:45:07.8130000Z',
#   'data_quote_end': '2021-04-17T15:09:58.9027361Z',
#   'data_orderbook_start': '2015-08-10T13:45:07.8130000Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.0488795Z',
#   'data_trade_start': '2016-10-17T14:02:50.4630000Z',
#   'data_trade_end': '2021-04-17T15:10:09.5630000Z',
#   'volume_1hrs': 3181.2539437,
#   'volume_1hrs_usd': 7530294.01,
#   'volume_1day': 50555.77643074,
#   'volume_1day_usd': 119669748.85,
#   'volume_1mth': 1626628.31211529,
#   'volume_1mth_usd': 3850365187.38,
#   'price': 2363.185,
#   'symbol_id_exchange': 'ETH/USD',
#   'asset_id_base_exchange': 'XETH',
#   'asset_id_quote_exchange': 'ZUSD',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_ETH_GBP',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'GBP',
#   'data_start': '2015-08-10',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-08-10T13:45:07.8130000Z',
#   'data_quote_end': '2021-04-17T15:09:58.3389003Z',
#   'data_orderbook_start': '2015-08-10T13:45:07.8130000Z',
#   'data_orderbook_end': '2020-08-05T14:37:19.6705434Z',
#   'data_trade_start': '2016-10-17T16:51:44.6130000Z',
#   'data_trade_end': '2021-04-17T14:59:33.6760000Z',
#   'volume_1hrs': 27.63505654,
#   'volume_1hrs_usd': 65414.49,
#   'volume_1day': 823.272719,
#   'volume_1day_usd': 1948755.34,
#   'volume_1mth': 29050.07981567,
#   'volume_1mth_usd': 68763967.27,
#   'price': 1720.585,
#   'symbol_id_exchange': 'ETH/GBP',
#   'asset_id_base_exchange': 'XETH',
#   'asset_id_quote_exchange': 'ZGBP',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'KRAKEN_SPOT_ETH_JPY',
#   'exchange_id': 'KRAKEN',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'JPY',
#   'data_start': '2015-08-10',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-08-10T13:45:07.8130000Z',
#   'data_quote_end': '2021-04-17T15:09:57.9377724Z',
#   'data_orderbook_start': '2015-08-10T13:45:07.8130000Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.0838521Z',
#   'data_trade_start': '2016-10-18T04:27:09.1840000Z',
#   'data_trade_end': '2021-04-17T14:10:42.4450000Z',
#   'volume_1day': 34.27825133,
#   'volume_1day_usd': 81139.49,
#   'volume_1mth': 1116.3927485,
#   'volume_1mth_usd': 2642594.96,
#   'price': 257356.0,
#   'symbol_id_exchange': 'ETH/JPY',
#   'asset_id_base_exchange': 'XETH',
#   'asset_id_quote_exchange': 'ZJPY',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'BITMEX_PERP_BTC_USD',
#   'exchange_id': 'BITMEX',
#   'symbol_type': 'PERPETUAL',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'asset_id_unit': 'USD',
#   'future_contract_unit': 1.0,
#   'future_contract_unit_asset': 'USD',
#   'data_start': '2015-09-25',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2015-09-25T12:04:42.8771610Z',
#   'data_quote_end': '2021-04-17T15:09:56.3047279Z',
#   'data_orderbook_start': '2015-09-25T12:04:42.8771610Z',
#   'data_orderbook_end': '2020-08-05T14:37:16.1266801Z',
#   'data_trade_start': '2015-09-25T12:34:25.0000000Z',
#   'data_trade_end': '2021-04-17T15:10:05.1160000Z',
#   'volume_1hrs': 103155173.0,
#   'volume_1hrs_usd': 103155173.0,
#   'volume_1day': 2019910620.0,
#   'volume_1day_usd': 2019910620.0,
#   'volume_1mth': 88292288394.0,
#   'volume_1mth_usd': 88292288394.0,
#   'price': 60472.25,
#   'symbol_id_exchange': 'XBTUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.1,
#   'size_precision': 1.0},
#  {'symbol_id': 'BIT2C_SPOT_LTC_NIS',
#   'exchange_id': 'BIT2C',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'NIS',
#   'data_start': '2014-02-08',
#   'data_end': '2019-08-28',
#   'data_quote_start': '2018-01-24T00:42:50.1443495Z',
#   'data_quote_end': '2019-08-28T13:13:35.2728239Z',
#   'data_orderbook_start': '2018-01-24T00:42:50.1443495Z',
#   'data_orderbook_end': '2019-08-28T13:13:35.2728239Z',
#   'data_trade_start': '2014-02-08T22:14:00.0000000Z',
#   'data_trade_end': '2019-08-28T07:16:29.0000000Z',
#   'symbol_id_exchange': 'LtsNis',
#   'asset_id_base_exchange': 'LTC',
#   'asset_id_quote_exchange': 'NIS',
#   'price_precision': 0.01,
#   'size_precision': 1e-08},
#  {'symbol_id': 'GEMINI_SPOT_BTC_USD',
#   'exchange_id': 'GEMINI',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'data_start': '2015-10-08',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:53:42.2753836Z',
#   'data_quote_end': '2021-04-17T15:01:57.7780000Z',
#   'data_orderbook_start': '2017-03-18T22:53:42.2753836Z',
#   'data_orderbook_end': '2020-08-05T14:37:04.9340000Z',
#   'data_trade_start': '2015-10-08T13:40:07.8010000Z',
#   'data_trade_end': '2021-04-17T15:02:34.6120000Z',
#   'volume_1hrs': 34.765335572,
#   'volume_1hrs_usd': 2101771.95,
#   'volume_1day': 683.116134788,
#   'volume_1day_usd': 41298445.97,
#   'volume_1mth': 41702.657725252,
#   'volume_1mth_usd': 2521174467.03,
#   'price': 60429.95,
#   'symbol_id_exchange': 'BTCUSD',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 0.01,
#   'size_precision': 1e-09},
#  {'symbol_id': 'VBTC_SPOT_BTC_VND',
#   'exchange_id': 'VBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'VND',
#   'data_start': '2015-09-09',
#   'data_end': '2021-02-18',
#   'data_quote_start': '2017-03-14T20:05:05.6371921Z',
#   'data_quote_end': '2021-02-18T03:53:14.3949905Z',
#   'data_orderbook_start': '2017-03-14T20:05:05.6371921Z',
#   'data_orderbook_end': '2020-08-05T14:34:57.4067142Z',
#   'data_trade_start': '2015-09-09T03:09:55.0000000Z',
#   'data_trade_end': '2015-11-23T06:07:39.0000000Z',
#   'symbol_id_exchange': 'VBTC',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'VND',
#   'price_precision': 1.0,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_CB_BTC',
# ...
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'DOGE',
#   'asset_id_quote': 'RUB',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T23:27:29.5123070Z',
#   'data_quote_end': '2021-04-17T15:03:43.0352465Z',
#   'data_orderbook_start': '2017-03-18T23:27:29.5123070Z',
#   'data_orderbook_end': '2020-05-11T22:54:58.8202341Z',
#   'data_trade_start': '2017-03-18T17:34:13.0000000Z',
#   'data_trade_end': '2021-04-17T15:08:43.0000000Z',
#   'volume_1hrs': 36813.77194838,
#   'volume_1hrs_usd': 9448.35,
#   'volume_1day': 640093.60541811,
#   'volume_1day_usd': 164281.74,
#   'volume_1mth': 10143712.87989456,
#   'volume_1mth_usd': 2603411.08,
#   'price': 20.169,
#   'symbol_id_exchange': 'DOGE_RUR',
#   'asset_id_base_exchange': 'DOGE',
#   'asset_id_quote_exchange': 'RUB',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_PTA_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'PTA',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T23:48:56.8354530Z',
#   'data_quote_end': '2021-04-17T09:30:42.1567126Z',
#   'data_orderbook_start': '2017-03-18T23:48:56.8354530Z',
#   'data_orderbook_end': '2019-08-01T23:35:42.7326587Z',
#   'data_trade_start': '2017-03-18T12:20:35.0000000Z',
#   'data_trade_end': '2021-04-16T13:36:25.0000000Z',
#   'volume_1mth': 3838.41706891,
#   'price': 2.1e-07,
#   'symbol_id_exchange': 'PTA_BTC',
#   'asset_id_base_exchange': 'pta',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'HITBTC_SPOT_DOGE_BTC',
#   'exchange_id': 'HITBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'DOGE',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:53:49.8502094Z',
#   'data_quote_end': '2021-04-17T15:09:59.8320568Z',
#   'data_orderbook_start': '2017-03-18T22:53:49.8502094Z',
#   'data_orderbook_end': '2020-08-05T14:37:18.0227093Z',
#   'data_trade_start': '2017-03-18T18:00:52.7460000Z',
#   'data_trade_end': '2021-04-17T15:10:06.0000000Z',
#   'volume_1hrs': 1575170.0,
#   'volume_1hrs_usd': 404271.6,
#   'volume_1day': 72664070.0,
#   'volume_1day_usd': 18649428.2,
#   'volume_1mth': 10520468270.0,
#   'volume_1mth_usd': 2700106361.44,
#   'price': 2.991085e-06,
#   'symbol_id_exchange': 'DOGEBTC',
#   'asset_id_base_exchange': 'DOGE',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-09,
#   'size_precision': 1.0},
#  {'symbol_id': 'YOBIT_SPOT_BIOB_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BIOB',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T23:59:34.5596670Z',
#   'data_quote_end': '2021-04-17T15:09:51.0499480Z',
#   'data_orderbook_start': '2017-03-18T23:59:34.5596670Z',
#   'data_orderbook_end': '2019-08-01T23:35:46.1067567Z',
#   'data_trade_start': '2017-03-18T18:09:10.0000000Z',
#   'data_trade_end': '2021-04-16T15:42:10.0000000Z',
#   'volume_1day': 2532.32467064,
#   'volume_1mth': 10239.95814821,
#   'price': 6e-08,
#   'symbol_id_exchange': 'BIOB_BTC',
#   'asset_id_base_exchange': 'biob',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_DASH_USD',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'DASH',
#   'asset_id_quote': 'USD',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T23:28:40.7236284Z',
#   'data_quote_end': '2021-04-17T15:03:43.0352465Z',
#   'data_orderbook_start': '2017-03-18T23:28:40.7236284Z',
#   'data_orderbook_end': '2020-05-11T22:54:58.8202341Z',
#   'data_trade_start': '2017-03-18T18:06:24.0000000Z',
#   'data_trade_end': '2021-04-17T14:52:50.0000000Z',
#   'volume_1hrs': 0.22892243,
#   'volume_1hrs_usd': 84.39,
#   'volume_1day': 90.3566407,
#   'volume_1day_usd': 33310.94,
#   'volume_1mth': 1045.56846328,
#   'volume_1mth_usd': 385459.92,
#   'price': 391.09,
#   'symbol_id_exchange': 'DASH_USD',
#   'asset_id_base_exchange': 'DASH',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_KC_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'KC',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-19T02:40:15.1859505Z',
#   'data_quote_end': '2021-04-17T13:02:51.6859415Z',
#   'data_orderbook_start': '2017-03-19T02:40:15.1859505Z',
#   'data_orderbook_end': '2019-08-01T23:35:42.3949008Z',
#   'data_trade_start': '2017-03-18T16:14:57.0000000Z',
#   'data_trade_end': '2021-04-16T14:12:19.0000000Z',
#   'volume_1mth': 9649.2793588,
#   'price': 1.9e-07,
#   'symbol_id_exchange': 'KC_BTC',
#   'asset_id_base_exchange': 'kc',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_HALLO_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'HALLO',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-12',
#   'data_end': '2021-04-11',
#   'data_quote_start': '2017-03-18T23:48:57.4020185Z',
#   'data_quote_end': '2021-04-11T15:41:14.2882902Z',
#   'data_orderbook_start': '2017-03-18T23:48:57.4020185Z',
#   'data_orderbook_end': '2019-08-01T23:35:45.8331597Z',
#   'data_trade_start': '2017-03-12T19:01:54.0000000Z',
#   'data_trade_end': '2020-04-22T10:58:19.0000000Z',
#   'symbol_id_exchange': 'HALLO_BTC',
#   'asset_id_base_exchange': 'hallo',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 1e-07},
#  {'symbol_id': 'YOBIT_SPOT_ETH_RUB',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'RUB',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-19T01:06:17.3004053Z',
#   'data_quote_end': '2021-04-17T15:03:43.0352465Z',
#   'data_orderbook_start': '2017-03-19T01:06:17.3004053Z',
#   'data_orderbook_end': '2020-05-11T22:49:00.7812547Z',
#   'data_trade_start': '2017-03-18T19:18:50.0000000Z',
#   'data_trade_end': '2021-04-17T15:03:58.0000000Z',
#   'volume_1hrs': 2.2122465,
#   'volume_1hrs_usd': 5236.57,
#   'volume_1day': 50.86941938,
#   'volume_1day_usd': 120412.17,
#   'volume_1mth': 2964.72872671,
#   'volume_1mth_usd': 7017760.72,
#   'price': 182100,
#   'symbol_id_exchange': 'ETH_RUR',
#   'asset_id_base_exchange': 'ETH',
#   'asset_id_quote_exchange': 'RUB',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_SPKTR_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'SPKTR',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-19T00:13:48.8858924Z',
#   'data_quote_end': '2021-04-17T09:11:54.4483097Z',
#   'data_orderbook_start': '2017-03-19T00:13:48.8858924Z',
#   'data_orderbook_end': '2019-08-02T06:58:06.3456696Z',
#   'data_trade_start': '2017-03-18T13:30:10.0000000Z',
#   'data_trade_end': '2021-04-16T17:36:05.0000000Z',
#   'volume_1day': 1458.64828571,
#   'volume_1mth': 11533.62208567,
#   'price': 6.5e-08,
#   'symbol_id_exchange': 'SPKTR_BTC',
#   'asset_id_base_exchange': 'spktr',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_ETH_USD',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'USD',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T23:48:57.0894947Z',
#   'data_quote_end': '2021-04-17T15:03:43.0352465Z',
#   'data_orderbook_start': '2017-03-18T23:48:57.0894947Z',
#   'data_orderbook_end': '2020-05-11T22:54:58.8202341Z',
#   'data_trade_start': '2017-03-18T19:30:04.0000000Z',
#   'data_trade_end': '2021-04-17T15:01:13.0000000Z',
#   'volume_1hrs': 12.11531833,
#   'volume_1hrs_usd': 28677.97,
#   'volume_1day': 65.26320187,
#   'volume_1day_usd': 154483.45,
#   'volume_1mth': 1974.95137731,
#   'volume_1mth_usd': 4674875.0,
#   'price': 2396.09857975,
#   'symbol_id_exchange': 'ETH_USD',
#   'asset_id_base_exchange': 'ETH',
#   'asset_id_quote_exchange': 'USD',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'HITBTC_SPOT_LSK_BTC',
#   'exchange_id': 'HITBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LSK',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:54:38.5820073Z',
#   'data_quote_end': '2021-04-17T15:10:09.4300358Z',
#   'data_orderbook_start': '2017-03-18T22:54:38.5820073Z',
#   'data_orderbook_end': '2020-08-05T14:37:16.2889649Z',
#   'data_trade_start': '2017-03-18T19:52:31.1750000Z',
#   'data_trade_end': '2021-04-17T14:58:08.0000000Z',
#   'volume_1hrs': 9334.43,
#   'volume_1hrs_usd': 61522.91,
#   'volume_1day': 715668.48,
#   'volume_1day_usd': 4716946.37,
#   'volume_1mth': 28419347.27,
#   'volume_1mth_usd': 187310941.61,
#   'price': 0.00010892,
#   'symbol_id_exchange': 'LSKBTC',
#   'asset_id_base_exchange': 'LSK',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-08,
#   'size_precision': 0.01},
#  {'symbol_id': 'HITBTC_SPOT_XEM_BTC',
#   'exchange_id': 'HITBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'XEM',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:54:07.0950857Z',
#   'data_quote_end': '2021-04-17T15:09:57.6903688Z',
#   'data_orderbook_start': '2017-03-18T22:54:07.0950857Z',
#   'data_orderbook_end': '2020-08-05T14:33:27.4761962Z',
#   'data_trade_start': '2017-03-18T19:58:10.6490000Z',
#   'data_trade_end': '2021-04-17T15:10:32.0000000Z',
#   'volume_1hrs': 3106018.0,
#   'volume_1hrs_usd': 1507235.65,
#   'volume_1day': 53261043.0,
#   'volume_1day_usd': 25845614.19,
#   'volume_1mth': 919701042.0,
#   'volume_1mth_usd': 446296898.51,
#   'price': 8.0225e-06,
#   'symbol_id_exchange': 'XEMBTC',
#   'asset_id_base_exchange': 'XEM',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-09,
#   'size_precision': 1.0},
#  {'symbol_id': 'HITBTC_SPOT_LTC_BTC',
#   'exchange_id': 'HITBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LTC',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:54:10.1504839Z',
#   'data_quote_end': '2021-04-17T15:09:57.1548133Z',
#   'data_orderbook_start': '2017-03-18T22:54:10.1504839Z',
#   'data_orderbook_end': '2020-08-05T14:37:20.0967303Z',
#   'data_trade_start': '2017-03-18T20:12:32.2310000Z',
#   'data_trade_end': '2021-04-17T15:10:30.0000000Z',
#   'volume_1hrs': 3639.359,
#   'volume_1hrs_usd': 1130247.97,
#   'volume_1day': 370677.273,
#   'volume_1day_usd': 115118413.91,
#   'volume_1mth': 4680291.06,
#   'volume_1mth_usd': 1453522302.82,
#   'price': 0.00513415,
#   'symbol_id_exchange': 'LTCBTC',
#   'asset_id_base_exchange': 'LTC',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-07,
#   'size_precision': 0.001},
#  {'symbol_id': 'YOBIT_SPOT_ZEC_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'ZEC',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-19T00:46:16.5437869Z',
#   'data_quote_end': '2021-04-17T15:09:01.9400063Z',
#   'data_orderbook_start': '2017-03-19T00:46:16.5437869Z',
#   'data_orderbook_end': '2019-08-02T17:41:56.5356798Z',
#   'data_trade_start': '2017-03-18T20:41:28.0000000Z',
#   'data_trade_end': '2021-04-17T14:44:27.0000000Z',
#   'volume_1hrs': 13812.029757,
#   'volume_1hrs_usd': 3846454.16,
#   'volume_1day': 333082.54072189,
#   'volume_1day_usd': 92758757.86,
#   'volume_1mth': 14925411.77396507,
#   'volume_1mth_usd': 4156515240.01,
#   'price': 0.00462381,
#   'symbol_id_exchange': 'ZEC_BTC',
#   'asset_id_base_exchange': 'ZEC',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_DOGE_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'DOGE',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T23:56:48.9497202Z',
#   'data_quote_end': '2021-04-17T14:53:59.2640315Z',
#   'data_orderbook_start': '2017-03-18T23:56:48.9497202Z',
#   'data_orderbook_end': '2019-08-02T17:41:31.5387427Z',
#   'data_trade_start': '2017-03-18T20:44:52.0000000Z',
#   'data_trade_end': '2021-04-17T15:02:04.0000000Z',
#   'volume_1hrs': 93134.24745368,
#   'volume_1hrs_usd': 23903.15,
#   'volume_1day': 32220206.67708019,
#   'volume_1day_usd': 8269402.35,
#   'volume_1mth': 307464343.1602627,
#   'volume_1mth_usd': 78911547.24,
#   'price': 4.295e-06,
#   'symbol_id_exchange': 'DOGE_BTC',
#   'asset_id_base_exchange': 'DOGE',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_BTC_RUB',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'RUB',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-19T00:06:34.5271350Z',
#   'data_quote_end': '2021-04-17T15:03:43.0352465Z',
#   'data_orderbook_start': '2017-03-19T00:06:34.5271350Z',
#   'data_orderbook_end': '2020-08-05T14:28:30.0033299Z',
#   'data_trade_start': '2017-03-18T20:49:53.0000000Z',
#   'data_trade_end': '2021-04-17T15:04:08.0000000Z',
#   'volume_1hrs': 0.1431531,
#   'volume_1hrs_usd': 8654.46,
#   'volume_1day': 6.60550686,
#   'volume_1day_usd': 399342.3,
#   'volume_1mth': 160.46669275,
#   'volume_1mth_usd': 9701168.96,
#   'price': 4609035.0000001,
#   'symbol_id_exchange': 'BTC_RUR',
#   'asset_id_base_exchange': 'BTC',
#   'asset_id_quote_exchange': 'RUB',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_VIDZ_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'VIDZ',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-19T00:32:16.7104604Z',
#   'data_quote_end': '2021-04-17T14:43:20.9476815Z',
#   'data_orderbook_start': '2017-03-19T00:32:16.7104604Z',
#   'data_orderbook_end': '2019-08-02T09:41:27.0339247Z',
#   'data_trade_start': '2017-03-18T20:39:05.0000000Z',
#   'data_trade_end': '2021-04-11T18:55:06.0000000Z',
#   'volume_1mth': 29306.33732534,
#   'price': 1.5e-08,
#   'symbol_id_exchange': 'VIDZ_BTC',
#   'asset_id_base_exchange': 'vidz',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'YOBIT_SPOT_LIZI_BTC',
#   'exchange_id': 'YOBIT',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'LIZI',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T23:33:28.0763733Z',
#   'data_quote_end': '2021-04-17T14:19:06.9409741Z',
#   'data_orderbook_start': '2017-03-18T23:33:28.0763733Z',
#   'data_orderbook_end': '2019-08-02T17:37:48.4369125Z',
#   'data_trade_start': '2017-03-18T20:42:28.0000000Z',
#   'data_trade_end': '2021-04-16T21:25:39.0000000Z',
#   'volume_1day': 37.7443439,
#   'volume_1mth': 308.10506499,
#   'price': 7.535e-06,
#   'symbol_id_exchange': 'LIZI_BTC',
#   'asset_id_base_exchange': 'lizi',
#   'asset_id_quote_exchange': 'btc',
#   'price_precision': 1e-08,
#   'size_precision': 1e-08},
#  {'symbol_id': 'HITBTC_SPOT_BCN_BTC',
#   'exchange_id': 'HITBTC',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BCN',
#   'asset_id_quote': 'BTC',
#   'data_start': '2017-03-18',
#   'data_end': '2021-04-17',
#   'data_quote_start': '2017-03-18T22:53:44.4091161Z',
#   'data_quote_end': '2021-04-17T15:10:26.4753841Z',
#   'data_orderbook_start': '2017-03-18T22:53:44.4091161Z',
#   'data_orderbook_end': '2020-08-05T14:35:32.0074377Z',
#   'data_trade_start': '2017-03-18T22:14:20.6820000Z',
#   'data_trade_end': '2021-04-17T15:05:25.0000000Z',
#   'volume_1hrs': 3732300.0,
#   'volume_1hrs_usd': 3689.87,
#   'volume_1day': 115198400.0,
#   'volume_1day_usd': 113888.7,
#   'volume_1mth': 3042662700.0,
#   'volume_1mth_usd': 3008070.39,
#   'price': 1.4675e-08,
#   'symbol_id_exchange': 'BCNBTC',
#   'asset_id_base_exchange': 'BCN',
#   'asset_id_quote_exchange': 'BTC',
#   'price_precision': 1e-09,
#   'size_precision': 1.0},
#  ...]
