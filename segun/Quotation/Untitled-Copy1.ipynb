# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\segun\appdata\local\programs\python\python37-32\python.exe -m pip install --upgrade pip' command.

# %%
pd.read_excel("QG061-BM-AM-19 CG260-16.Rev4-26-11-2020.xlsx")
# Out:
#                                   Unnamed: 0  \
# 0                                        NaN
# 1                               26 Nov, 2020
# 2   Summary for Installation of 5 X CG260-16
# 3                                       ITEM
# 4                                          1
# 5                                          2
# 6                                          3
# 7                                  SUB-TOTAL
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
#
#                                            Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                         DESCRIPTION         NaN
# ...

# %%
# !pip install xlrd
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\segun\appdata\local\programs\python\python37-32\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\segun\appdata\local\programs\python\python37-32\python.exe -m pip install --upgrade pip' command.
# ...
