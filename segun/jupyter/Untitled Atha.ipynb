# %%
import requests

# %%
# data = requests.get("https://www.jumia.com.ng/")

# %%
# data.content

# %%
import requests
url = 'https://rest.coinapi.io/v1/assets'
headers = {'X-CoinAPI-Key' : '424A42C1-397B-4866-B0E3-19D1691BC592'}
response = requests.get(url, headers=headers)

# %%
data = response.json()

# %%
data
# Out:
# [{'asset_id': 'BTC',
#   'name': 'Bitcoin',
#   'type_is_crypto': 1,
#   'data_start': '2010-07-17',
#   'data_end': '2021-04-24',
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2021-04-24T11:22:51.1058366Z',
#   'data_orderbook_start': '2014-02-24T17:43:05.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:38:38.3413202Z',
#   'data_trade_start': '2010-07-17T23:09:17.0000000Z',
#   'data_trade_end': '2021-04-24T12:27:50.0000000Z',
#   'data_symbols_count': 52299,
#   'volume_1hrs_usd': 106603812583502.31,
#   'volume_1day_usd': 5.4574418288857464e+16,
#   'volume_1mth_usd': 1.2204598986272817e+18,
#   'price_usd': 49419.27733321115,
#   'id_icon': '4caf2b16-a017-4e26-a348-2cea69c34cba'},
#  {'asset_id': 'USD',
#   'name': 'US Dollar',
#   'type_is_crypto': 0,
#   'data_start': '2010-07-17',
#   'data_end': '2021-04-24',
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2021-04-24T11:22:50.9591566Z',
# ...

# %%
type(data[1])
# Out:
# dict

# %%
dummy_structure = [{},{},{},{},{}]
for empty_dict in dummy_structure:
    print(empty_dict)
# Out:
# {}
# {}
# {}
# {}
# {}

# %%
for currency_dict in data:
#     print(currency_dict)
    print(currency_dict.get("name", "N/A"))
    print("=========================================")
# Out:
# Bitcoin
# ...
# US Dollar
# ...
# Zloty
# ...
# Euro
# ...
# Yuan Renminbi
# ...
# Yen
# ...
# Australian Dollar
# ...
# Swiss Franc
# ...
# Swedish Krona
# ...
# Pound Sterling
# ...
# Danish Krone
# ...
# Russian Ruble
# ...
# Singapore Dollar
# ...
# Canadian Dollar
# ...
# New Zealand Dollar
# ...
# Baht
# ...
# Leone
# ...
# NIS
# ...
# Litecoin
# ...
# Won
# ...
# VeChain (pre-swap)
# ...
# Ripple
# ...
# Namecoin
# ...
# Tether
# ...
# Blakecoin
# ...
# DogeCoin
# ...
# Novacoin
# ...
# Feathercoin
# ...
# Peercoin
# ...
# Terracoin
# ...
# El Salvador Colon
# ...
# StrikeBitClub
# ...
# ORO
# ...
# Torcoin
# ...
# Bolivar Fuerte
# ...
# StarCoin
# ...
# BitShares
# ...
# Nxt
# ...
# Burst
# ...
# Pakistan Rupee
# ...
# bitCNY
# ...
# UCoin
# ...
# Brazilian Real
# ...
# Chilean Peso
# ...
# WINCOIN
# ...
# MonetaryUnit
# ...
# SongCoin
# ...
# PayCon
# ...
# NAVCoin
# ...
# MCC
# ...
# RICE
# ...
# GeoCoin
# ...
# BitSend
# ...
# TopCoin
# ...
# RedCoin
# ...
# ETCO
# ...
# AmberCoin
# ...
# Metal Music Coin
# ...
# Guncoin
# ...
# Titcoin
# ...
# Natcoin
# ...
# Crave
# ...
# Fonziecoin
# ...
# SQL
# ...
# DUCK
# ...
# OZC
# ...
# LUXCoin
# ...
# Boliviano
# ...
# Advanced Internet Blocks
# ...
# AnarchistsPrime
# ...
# Bitcore
# ...
# Droidz
# ...
# GlobalBoost-Y
# ...
# BitBay
# ...
# Phoenixcoin
# ...
# Woodcoin
# ...
# Deutsche Mark
# ...
# FLN
# ...
# Crown
# ...
# Skeincoin
# ...
# LTS
# ...
# Marscoin
# ...
# Unobtanium
# ...
# Verge
# ...
# DigiByte
# ...

# %%
i = 0

for currency_dict in data:
    file.write(f'{currency_dict.get("name", "N/A")}, (currency)')
