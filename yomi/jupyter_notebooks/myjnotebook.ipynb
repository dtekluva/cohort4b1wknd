# %%
print(1+1)
# Out:
# 2

# %%
# !pip install requests
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe26813cf70>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/29/c1/24814557f1d22c56d50280771a17307e6bf87b70727d975fd6b2ce6b014a/requests-2.25.1-py2.py3-none-any.whl
# ...
#      |████████████████████████████████| 61 kB 208 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 147 kB 449 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 178 kB 412 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 1.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 153 kB 591 kB/s eta 0:00:01
# ...

# %%
import requests

# %%
# data = requests.get("https://www.jumia.com.ng")

# %%
url = 'https://rest.coinapi.io/v1/assets'
headers = {'X-CoinAPI-Key' : '09B8384B-CB90-4F95-9AD9-1D81195F8701'}
response = requests.get(url, headers=headers)

# %%
data = response.json()

# %%
dummy_structure = [{},{},{},{},{}]
for empty_dict in dummy_structure:
    print(empty_dict)
# Out:
# {}
# {}
# {}
# {}
# {}

# %%
data
# Out:
# [{'asset_id': 'BTC',
#   'name': 'Bitcoin',
#   'type_is_crypto': 1,
#   'data_start': '2010-07-17',
#   'data_end': '2021-04-24',
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2021-04-24T11:22:51.1058366Z',
#   'data_orderbook_start': '2014-02-24T17:43:05.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:38:38.3413202Z',
#   'data_trade_start': '2010-07-17T23:09:17.0000000Z',
#   'data_trade_end': '2021-04-24T12:27:50.0000000Z',
#   'data_symbols_count': 52299,
#   'volume_1hrs_usd': 106603812583502.31,
#   'volume_1day_usd': 5.4574418288857464e+16,
#   'volume_1mth_usd': 1.2204598986272817e+18,
#   'price_usd': 49419.27733321115,
#   'id_icon': '4caf2b16-a017-4e26-a348-2cea69c34cba'},
#  {'asset_id': 'USD',
#   'name': 'US Dollar',
#   'type_is_crypto': 0,
#   'data_start': '2010-07-17',
#   'data_end': '2021-04-24',
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2021-04-24T11:22:50.9591566Z',
# ...

# %%
file_name = "crypto.csv"
file = open(file_name, "w")

# %%
i = 0
for currency_dict in data:
#     print(currency_dict)
    print (f'(currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))\n')
#     print("=================")
    
    if i==50:
        break
        
    i+=1
# Out:
# (currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))
#
# (currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))
#
# (currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))
#
# (currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))
#
# (currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))
#
# (currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))
#
# (currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))
#
# (currency_dict.get("name", "N/A")), (currency_dict.get("data_start", "N/A")), (currency_dict.get("price_usd", "N/A"))
#
# ...

# %%
file.close()
