# %%
# !pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 43 kB 4.6 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pymysql.cursors

# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='',
                             database='test',
                             cursorclass=pymysql.cursors.DictCursor)

with connection:
    with connection.cursor() as cursor:
        sql = "SELECT name FROM users"
#         username = "Rukia"
#         name = "Rukia Sasuke"
#         age = 22
#         nation = "Japan"
        
#         # Create a new record
#         sql = f'INSERT INTO `users` (username, name, age, nation) VALUES ("{username}", "{name}", "{age}", "{nation}")'
#         print(sql)
        cursor.execute(sql)
        result = cursor.fetchmany(4)
        print(result)

    # connection is not autocommit by default. So you must commit to save
    # your changes.
    connection.commit()
# Out:
# [{'name': 'John'}, {'name': 'Ahmed'}, {'name': 'Miller'}, {'name': 'Rukia Sasuke'}]

# %%
names["x", "y", "z" ]
ages = [20, 32, 29]
u

# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.7 MB 41 kB/s eta 0:00:01     |██████████████████████████      | 8.7 MB 39 kB/s eta 0:00:50
# ...
#      |████████████████████████████████| 16.1 MB 25 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 16 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pandas as pd
data = pd.read_csv(r"/Users/Yomi/Documents/cohort4b1wknd/materials/statement2.csv")

# %%
data
# Out:
#       Txn Date        Date            Ref No  Withdrawls  Lodgements  \
# 0          NaN         NaN               NaN        0.00         0.0
# 1   31/03/2021  01/04/2021  071ICEDNGN 00001        3.43         0.0
# 2   01/04/2021  01/04/2021  099MJKL210915zGn      500.00         0.0
# 3   01/04/2021  01/04/2021  099MNIP210913g7i        0.00    132600.0
# 4   01/04/2021  01/04/2021  099MJKL21091AlBH      100.00         0.0
# ..         ...         ...               ...         ...         ...
# 79  23/04/2021  23/04/2021  099MNIP211130d0Z        0.00     50000.0
# 80  23/04/2021  23/04/2021  099MJKL211132hdR    10026.88         0.0
# 81  23/04/2021  23/04/2021  099MJKL211132lwd    10026.88         0.0
# 82  23/04/2021  23/04/2021  099MJKL211134GVZ    30026.88         0.0
# 83  23/04/2021  23/04/2021  099MNIP211133U7o        0.00     40000.0
#
#        Balance                                     Description  Unnamed: 7  \
# ...

# %%
data.describe()
# Out:
#           Withdrawls     Lodgements       Balance  Unnamed: 7  Unnamed: 8
# count      84.000000      84.000000  8.400000e+01         0.0         0.0
# mean     9484.005119    8953.891429  9.641454e+05         NaN         NaN
# std     19613.207998   24528.794149  5.572199e+04         NaN         NaN
# min         0.000000       0.000000  9.051635e+05         NaN         NaN
# 25%        40.875000       0.000000  9.196711e+05         NaN         NaN
# 50%      1010.750000       0.000000  9.482382e+05         NaN         NaN
# 75%     10026.880000       0.000000  9.930072e+05         NaN         NaN
# max    100053.750000  132600.000000  1.121790e+06         NaN         NaN

# %%
summary = data.describe()
summary.to_csv(r"/Users/Yomi/Documents/summary.csv") #write to csv format

# %%
# !pip install xlwt
# Out:
# ...
#      |████████████████████████████████| 99 kB 96 kB/s eta 0:00:011
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
summary = data.describe()
summary.to_excel(r"/Users/Yomi/Documents/summary.xls") #write to csv format
# Out:
# <ipython-input-27-28baa7aebd1e>:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   summary.to_excel(r"/Users/Yomi/Documents/summary.xls") #write to csv format

# %%
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 243 kB 28 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
for index, row in data.iterrows():
    print(row)
# Out:
# Txn Date                           NaN
# Date                               NaN
# Ref No                             NaN
# Withdrawls                         0.0
# Lodgements                         0.0
# Balance                      989693.06
# Description    Balance Brought Forward
# Unnamed: 7                         NaN
# Unnamed: 8                         NaN
# Name: 0, dtype: object
# Txn Date                           31/03/2021
# Date                               01/04/2021
# Ref No                       071ICEDNGN 00001
# Withdrawls                               3.43
# Lodgements                                0.0
# Balance                             989689.63
# Description    DEBIT INTEREST  CAPITALIZATION
# Unnamed: 7                                NaN
# Unnamed: 8                                NaN
# Name: 1, dtype: object
# Txn Date                       01/04/2021
# Date                           01/04/2021
# Ref No                   099MJKL210915zGn
# ...
